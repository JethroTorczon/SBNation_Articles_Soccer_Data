# %% [markdown]
# # Analysis — Serie A (20/21 season) — Data after Match Week 7

# %% [markdown]
# ## DataFrame #2  —  Squad DEFENSIVE ACTIONS

# %%
import pandas as pd
import numpy as np

# %%
from adjustText import adjust_text

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
#plt.style.use('seaborn-whitegrid')
#plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')

#fig, ax = plt.subplots()

# %%
#plt.style.use(['fivethirtyeight','dark_background'])
#plt.style.use(['seaborn','dark_background'])
#plt.style.use(['ggplot','dark_background'])
#plt.style.use(['seaborn-whitegrid','dark_background'])

plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

sns.set_context(
                'notebook',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %% [markdown]
# ## PART (1) — LOAD into DataFrame(s)

# %%
Squad_Shooting_df = pd.read_csv("Squad_Shooting.csv")

Squad_Shooting_df
# Out:
#             Squad  # Pl  90s  Gls   Sh  SoT  SoT_Pct  Sh_per_90  SoT_per_90  \
# 0        Atalanta    23  7.0   18  107   41     38.3      15.29        5.86
# 1       Benevento    21  7.0   10   68   25     36.8       9.71        3.57
# 2         Bologna    22  7.0   11  111   43     38.7      15.86        6.14
# 3        Cagliari    22  7.0   14   81   30     37.0      11.57        4.29
# 4         Crotone    25  7.0    6   68   18     26.5       9.71        2.57
# 5      Fiorentina    23  7.0   10   78   26     33.3      11.14        3.71
# 6           Genoa    26  7.0    7   62   19     30.6       8.86        2.71
# 7   Hellas Verona    26  7.0    6   72   27     37.5      10.29        3.86
# 8           Inter    22  7.0   15  118   40     33.9      16.86        5.71
# 9        Juventus    23  6.0   12   77   26     33.8      12.83        4.33
# 10          Lazio    25  7.0   11   88   26     29.5      12.57        3.71
# 11          Milan    23  7.0   15  113   36     31.9      16.14        5.14
# 12         Napoli    22  6.0   15  114   44     38.6      19.00        7.33
# 13          Parma    26  7.0    8   61   21     34.4       8.71        3.00
# 14           Roma    21  7.0   16  109   38     34.9      15.57        5.43
# 15      Sampdoria    24  7.0   11   74   25     33.8      10.57        3.57
# 16       Sassuolo    23  7.0   17  106   40     37.7      15.14        5.71
# 17         Spezia    30  7.0   11   74   26     35.1      10.57        3.71
# 18         Torino    22  7.0   11   64   26     40.6       9.14        3.71
# 19        Udinese    26  7.0    5   86   23     26.7      12.29        3.29
#
#     G_per_Sh  G_per_SoT  Dist  FK  PK  PKatt    xG  npxG  npxG_per_Sh  G_xG  \
# 0       0.16       0.41  16.8   5   1      1  13.4  12.7         0.12   4.6
# 1       0.15       0.40  16.7   4   0      1   7.9   7.0         0.11   2.1
# 2       0.10       0.26  17.2   6   0      0  10.0  10.0         0.09   1.0
# 3       0.16       0.43  16.5   5   1      1  10.2   9.5         0.12   3.8
# 4       0.06       0.22  18.4   3   2      2   7.0   5.4         0.08  -1.0
# 5       0.13       0.38  15.5   4   0      0  10.0  10.0         0.13   0.0
# 6       0.11       0.37  18.0   1   0      0   5.4   5.4         0.09   1.6
# 7       0.08       0.22  15.4   1   0      0   8.2   8.2         0.11  -2.2
# 8       0.13       0.38  15.7   1   0      0  14.9  14.9         0.13   0.1
# 9       0.13       0.38  16.6   5   2      2  11.9  10.3         0.14   0.1
# 10      0.11       0.38  16.7   2   1      1  10.1   9.4         0.11   0.9
# 11      0.11       0.33  16.0   8   3      5  16.5  12.5         0.12  -1.5
# 12      0.13       0.34  16.6   5   0      0  11.3  11.3         0.10   3.7
# 13      0.11       0.33  19.2   4   1      1   7.8   7.0         0.12   0.2
# 14      0.12       0.34  16.3   4   3      3  16.7  14.5         0.14  -0.7
# 15      0.14       0.40  18.1   2   1      2   8.7   7.2         0.10   2.3
# 16      0.13       0.35  16.7   6   3      3  13.1  10.8         0.11   3.9
# 17      0.15       0.42  18.0   0   0      0   5.8   5.8         0.08   5.2
# 18      0.14       0.35  16.6   3   2      2   8.9   7.4         0.12   2.1
# 19      0.05       0.17  17.2   0   1      1   9.0   8.3         0.10  -4.0
#
#     np_G_xG
# 0       4.3
# 1       3.0
# 2       1.0
# 3       3.5
# 4      -1.4
# 5       0.0
# 6       1.6
# 7      -2.2
# 8       0.1
# 9      -0.3
# 10      0.6
# 11     -0.5
# 12      3.7
# 13      0.0
# 14     -1.5
# 15      2.8
# 16      3.2
# 17      5.2
# 18      1.6
# 19     -4.3

# %% [markdown]
# ### Columns list:

# %%
columns_list = list(
                    Squad_Shooting_df.columns
                   )
columns_list
# Out:
# ['Squad',
#  '# Pl',
#  '90s',
#  'Gls',
#  'Sh',
#  'SoT',
#  'SoT_Pct',
#  'Sh_per_90',
#  'SoT_per_90',
#  'G_per_Sh',
#  'G_per_SoT',
#  'Dist',
#  'FK',
#  'PK',
#  'PKatt',
#  'xG',
#  'npxG',
#  'npxG_per_Sh',
#  'G_xG',
#  'np_G_xG']

# %% [markdown]
# ## PART (2) — identify RANKINGS per column

# %%
Squad_Shooting_Ranked_df = Squad_Shooting_df.rank(ascending = 0,
                                           #      '0' = 'False'
                                                  method = 'min')

Squad_Shooting_Ranked_df = Squad_Shooting_Ranked_df.astype(int)


Squad_Shooting_Ranked_df['Squad'] = list(map(str.upper,
                                             Squad_Shooting_df['Squad']
                                            )
                                        )
Squad_Shooting_Ranked_df
# Out:
#             Squad  # Pl  90s  Gls  Sh  SoT  SoT_Pct  Sh_per_90  SoT_per_90  \
# 0        ATALANTA     9    1    1   6    3        4          6           3
# 1       BENEVENTO    19    1   14  16   15        8         16          15
# 2         BOLOGNA    14    1    9   4    2        2          4           2
# 3        CAGLIARI    14    1    7  10    8        7         11           9
# 4         CROTONE     6    1   18  16   20       20         16          20
# 5      FIORENTINA     9    1   14  11   10       15         12          11
# 6           GENOA     2    1   17  19   19       17         19          19
# 7   HELLAS VERONA     2    1   18  15    9        6         15          10
# 8           INTER    14    1    4   1    4       12          2           4
# 9        JUVENTUS     9   19    8  12   10       13          8           8
# 10          LAZIO     6    1    9   8   10       18          9          11
# 11          MILAN     9    1    4   3    7       16          3           7
# 12         NAPOLI    14   19    4   2    1        3          1           1
# 13          PARMA     2    1   16  20   18       11         20          18
# 14           ROMA    19    1    3   5    6       10          5           6
# 15      SAMPDORIA     8    1    9  13   15       13         13          15
# 16       SASSUOLO     9    1    2   7    4        5          7           4
# 17         SPEZIA     1    1    9  13   10        9         13          11
# 18         TORINO    14    1    9  18   10        1         18          11
# 19        UDINESE     2    1   20   9   17       19         10          17
#
#     G_per_Sh  G_per_SoT  Dist  FK  PK  PKatt  xG  npxG  npxG_per_Sh  G_xG  \
# 0          1          3     8   4   7      8   4     3            5     2
# 1          3          4     9   8  13      8  16    16           10     7
# 2         17         17     6   2  13     14  10     8           17    10
# 3          1          1    15   4   7      8   8    10            5     4
# 4         19         18     2  12   4      4  18    19           19    17
# 5          7          6    19   8  13     14  10     8            3    15
# 6         13         10     4  16  13     14  20    19           17     9
# 7         18         18    20  16  13     14  15    13           10    19
# 8          7          6    18  16  13     14   3     1            3    13
# 9          7          6    12   4   4      4   6     7            1    13
# 10        13          6     9  14   7      8   9    11           10    11
# 11        13         15    17   1   1      1   2     4            5    18
# 12         7         13    12   4  13     14   7     5           14     5
# 13        13         15     1   8   7      8  17    16            5    12
# 14        12         13    16   8   1      2   1     2            1    16
# 15         5          4     3  14   7      4  14    15           14     6
# 16         7         11     9   2   1      2   5     6           10     3
# 17         3          2     4  19  13     14  19    18           19     1
# 18         5         11    12  12   4      4  13    14            5     7
# 19        20         20     6  19   7      8  12    12           14    20
#
#     np_G_xG
# 0         2
# 1         6
# 2        10
# 3         4
# 4        17
# 5        13
# 6         8
# 7        19
# 8        12
# 9        15
# 10       11
# 11       16
# 12        3
# 13       13
# 14       18
# 15        7
# 16        5
# 17        1
# 18        8
# 19       20

# %%
Squad_Shooting_Ranked_df.set_index('Squad',
                                   inplace = True)
Squad_Shooting_Ranked_df
# Out:
#                # Pl  90s  Gls  Sh  SoT  SoT_Pct  Sh_per_90  SoT_per_90  \
# Squad
# ATALANTA          9    1    1   6    3        4          6           3
# BENEVENTO        19    1   14  16   15        8         16          15
# BOLOGNA          14    1    9   4    2        2          4           2
# CAGLIARI         14    1    7  10    8        7         11           9
# CROTONE           6    1   18  16   20       20         16          20
# FIORENTINA        9    1   14  11   10       15         12          11
# GENOA             2    1   17  19   19       17         19          19
# HELLAS VERONA     2    1   18  15    9        6         15          10
# INTER            14    1    4   1    4       12          2           4
# JUVENTUS          9   19    8  12   10       13          8           8
# LAZIO             6    1    9   8   10       18          9          11
# MILAN             9    1    4   3    7       16          3           7
# NAPOLI           14   19    4   2    1        3          1           1
# PARMA             2    1   16  20   18       11         20          18
# ROMA             19    1    3   5    6       10          5           6
# SAMPDORIA         8    1    9  13   15       13         13          15
# SASSUOLO          9    1    2   7    4        5          7           4
# SPEZIA            1    1    9  13   10        9         13          11
# TORINO           14    1    9  18   10        1         18          11
# UDINESE           2    1   20   9   17       19         10          17
#
#                G_per_Sh  G_per_SoT  Dist  FK  PK  PKatt  xG  npxG  \
# Squad
# ATALANTA              1          3     8   4   7      8   4     3
# BENEVENTO             3          4     9   8  13      8  16    16
# BOLOGNA              17         17     6   2  13     14  10     8
# CAGLIARI              1          1    15   4   7      8   8    10
# CROTONE              19         18     2  12   4      4  18    19
# FIORENTINA            7          6    19   8  13     14  10     8
# GENOA                13         10     4  16  13     14  20    19
# HELLAS VERONA        18         18    20  16  13     14  15    13
# INTER                 7          6    18  16  13     14   3     1
# JUVENTUS              7          6    12   4   4      4   6     7
# LAZIO                13          6     9  14   7      8   9    11
# MILAN                13         15    17   1   1      1   2     4
# NAPOLI                7         13    12   4  13     14   7     5
# PARMA                13         15     1   8   7      8  17    16
# ROMA                 12         13    16   8   1      2   1     2
# SAMPDORIA             5          4     3  14   7      4  14    15
# SASSUOLO              7         11     9   2   1      2   5     6
# SPEZIA                3          2     4  19  13     14  19    18
# TORINO                5         11    12  12   4      4  13    14
# UDINESE              20         20     6  19   7      8  12    12
#
#                npxG_per_Sh  G_xG  np_G_xG
# Squad
# ATALANTA                 5     2        2
# BENEVENTO               10     7        6
# BOLOGNA                 17    10       10
# CAGLIARI                 5     4        4
# CROTONE                 19    17       17
# FIORENTINA               3    15       13
# GENOA                   17     9        8
# HELLAS VERONA           10    19       19
# INTER                    3    13       12
# JUVENTUS                 1    13       15
# LAZIO                   10    11       11
# MILAN                    5    18       16
# NAPOLI                  14     5        3
# PARMA                    5    12       13
# ROMA                     1    16       18
# SAMPDORIA               14     6        7
# SASSUOLO                10     3        5
# SPEZIA                  19     1        1
# TORINO                   5     7        8
# UDINESE                 14    20       20

# %%
Squad_Shooting_Ranks_Transposed = Squad_Shooting_Ranked_df.transpose()

Squad_Shooting_Ranks_Transposed
# Out:
# Squad        ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  FIORENTINA  \
# # Pl                9         19       14        14        6           9
# 90s                 1          1        1         1        1           1
# Gls                 1         14        9         7       18          14
# Sh                  6         16        4        10       16          11
# SoT                 3         15        2         8       20          10
# SoT_Pct             4          8        2         7       20          15
# Sh_per_90           6         16        4        11       16          12
# SoT_per_90          3         15        2         9       20          11
# G_per_Sh            1          3       17         1       19           7
# G_per_SoT           3          4       17         1       18           6
# Dist                8          9        6        15        2          19
# FK                  4          8        2         4       12           8
# PK                  7         13       13         7        4          13
# PKatt               8          8       14         8        4          14
# xG                  4         16       10         8       18          10
# npxG                3         16        8        10       19           8
# npxG_per_Sh         5         10       17         5       19           3
# G_xG                2          7       10         4       17          15
# np_G_xG             2          6       10         4       17          13
#
# Squad        GENOA  HELLAS VERONA  INTER  JUVENTUS  LAZIO  MILAN  NAPOLI  \
# # Pl             2              2     14         9      6      9      14
# 90s              1              1      1        19      1      1      19
# Gls             17             18      4         8      9      4       4
# Sh              19             15      1        12      8      3       2
# SoT             19              9      4        10     10      7       1
# SoT_Pct         17              6     12        13     18     16       3
# Sh_per_90       19             15      2         8      9      3       1
# SoT_per_90      19             10      4         8     11      7       1
# G_per_Sh        13             18      7         7     13     13       7
# G_per_SoT       10             18      6         6      6     15      13
# Dist             4             20     18        12      9     17      12
# FK              16             16     16         4     14      1       4
# PK              13             13     13         4      7      1      13
# PKatt           14             14     14         4      8      1      14
# xG              20             15      3         6      9      2       7
# npxG            19             13      1         7     11      4       5
# npxG_per_Sh     17             10      3         1     10      5      14
# G_xG             9             19     13        13     11     18       5
# np_G_xG          8             19     12        15     11     16       3
#
# Squad        PARMA  ROMA  SAMPDORIA  SASSUOLO  SPEZIA  TORINO  UDINESE
# # Pl             2    19          8         9       1      14        2
# 90s              1     1          1         1       1       1        1
# Gls             16     3          9         2       9       9       20
# Sh              20     5         13         7      13      18        9
# SoT             18     6         15         4      10      10       17
# SoT_Pct         11    10         13         5       9       1       19
# Sh_per_90       20     5         13         7      13      18       10
# SoT_per_90      18     6         15         4      11      11       17
# G_per_Sh        13    12          5         7       3       5       20
# G_per_SoT       15    13          4        11       2      11       20
# Dist             1    16          3         9       4      12        6
# FK               8     8         14         2      19      12       19
# PK               7     1          7         1      13       4        7
# PKatt            8     2          4         2      14       4        8
# xG              17     1         14         5      19      13       12
# npxG            16     2         15         6      18      14       12
# npxG_per_Sh      5     1         14        10      19       5       14
# G_xG            12    16          6         3       1       7       20
# np_G_xG         13    18          7         5       1       8       20

# %%
Squad_Shooting_Ranks_Transposed.reset_index(inplace = True)

Squad_Shooting_Ranks_Transposed.rename(columns = {'index':'SQUAD'
                                                 },
                                     # order = {
#                                                'OLD' : 'NEW'
#                                              }
                                       inplace = True)
Squad_Shooting_Ranks_Transposed
# Out:
# Squad        SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  \
# 0             # Pl         9         19       14        14        6
# 1              90s         1          1        1         1        1
# 2              Gls         1         14        9         7       18
# 3               Sh         6         16        4        10       16
# 4              SoT         3         15        2         8       20
# 5          SoT_Pct         4          8        2         7       20
# 6        Sh_per_90         6         16        4        11       16
# 7       SoT_per_90         3         15        2         9       20
# 8         G_per_Sh         1          3       17         1       19
# 9        G_per_SoT         3          4       17         1       18
# 10            Dist         8          9        6        15        2
# 11              FK         4          8        2         4       12
# 12              PK         7         13       13         7        4
# 13           PKatt         8          8       14         8        4
# 14              xG         4         16       10         8       18
# 15            npxG         3         16        8        10       19
# 16     npxG_per_Sh         5         10       17         5       19
# 17            G_xG         2          7       10         4       17
# 18         np_G_xG         2          6       10         4       17
#
# Squad  FIORENTINA  GENOA  HELLAS VERONA  INTER  ...  LAZIO  MILAN  NAPOLI  \
# 0               9      2              2     14  ...      6      9      14
# 1               1      1              1      1  ...      1      1      19
# 2              14     17             18      4  ...      9      4       4
# 3              11     19             15      1  ...      8      3       2
# 4              10     19              9      4  ...     10      7       1
# 5              15     17              6     12  ...     18     16       3
# 6              12     19             15      2  ...      9      3       1
# 7              11     19             10      4  ...     11      7       1
# 8               7     13             18      7  ...     13     13       7
# 9               6     10             18      6  ...      6     15      13
# 10             19      4             20     18  ...      9     17      12
# 11              8     16             16     16  ...     14      1       4
# 12             13     13             13     13  ...      7      1      13
# 13             14     14             14     14  ...      8      1      14
# 14             10     20             15      3  ...      9      2       7
# 15              8     19             13      1  ...     11      4       5
# 16              3     17             10      3  ...     10      5      14
# 17             15      9             19     13  ...     11     18       5
# 18             13      8             19     12  ...     11     16       3
#
# Squad  PARMA  ROMA  SAMPDORIA  SASSUOLO  SPEZIA  TORINO  UDINESE
# 0          2    19          8         9       1      14        2
# 1          1     1          1         1       1       1        1
# 2         16     3          9         2       9       9       20
# 3         20     5         13         7      13      18        9
# 4         18     6         15         4      10      10       17
# 5         11    10         13         5       9       1       19
# 6         20     5         13         7      13      18       10
# 7         18     6         15         4      11      11       17
# 8         13    12          5         7       3       5       20
# 9         15    13          4        11       2      11       20
# 10         1    16          3         9       4      12        6
# 11         8     8         14         2      19      12       19
# 12         7     1          7         1      13       4        7
# 13         8     2          4         2      14       4        8
# 14        17     1         14         5      19      13       12
# 15        16     2         15         6      18      14       12
# 16         5     1         14        10      19       5       14
# 17        12    16          6         3       1       7       20
# 18        13    18          7         5       1       8       20
#
# [19 rows x 21 columns]

# %%
Squad_Shooting_Rankings = Squad_Shooting_Ranks_Transposed.sort_values('INTER')
Squad_Shooting_Rankings
# Out:
# Squad        SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  \
# 1              90s         1          1        1         1        1
# 3               Sh         6         16        4        10       16
# 15            npxG         3         16        8        10       19
# 6        Sh_per_90         6         16        4        11       16
# 16     npxG_per_Sh         5         10       17         5       19
# 14              xG         4         16       10         8       18
# 2              Gls         1         14        9         7       18
# 4              SoT         3         15        2         8       20
# 7       SoT_per_90         3         15        2         9       20
# 9        G_per_SoT         3          4       17         1       18
# 8         G_per_Sh         1          3       17         1       19
# 18         np_G_xG         2          6       10         4       17
# 5          SoT_Pct         4          8        2         7       20
# 12              PK         7         13       13         7        4
# 17            G_xG         2          7       10         4       17
# 13           PKatt         8          8       14         8        4
# 0             # Pl         9         19       14        14        6
# 11              FK         4          8        2         4       12
# 10            Dist         8          9        6        15        2
#
# Squad  FIORENTINA  GENOA  HELLAS VERONA  INTER  ...  LAZIO  MILAN  NAPOLI  \
# 1               1      1              1      1  ...      1      1      19
# 3              11     19             15      1  ...      8      3       2
# 15              8     19             13      1  ...     11      4       5
# 6              12     19             15      2  ...      9      3       1
# 16              3     17             10      3  ...     10      5      14
# 14             10     20             15      3  ...      9      2       7
# 2              14     17             18      4  ...      9      4       4
# 4              10     19              9      4  ...     10      7       1
# 7              11     19             10      4  ...     11      7       1
# 9               6     10             18      6  ...      6     15      13
# 8               7     13             18      7  ...     13     13       7
# 18             13      8             19     12  ...     11     16       3
# 5              15     17              6     12  ...     18     16       3
# 12             13     13             13     13  ...      7      1      13
# 17             15      9             19     13  ...     11     18       5
# 13             14     14             14     14  ...      8      1      14
# 0               9      2              2     14  ...      6      9      14
# 11              8     16             16     16  ...     14      1       4
# 10             19      4             20     18  ...      9     17      12
#
# Squad  PARMA  ROMA  SAMPDORIA  SASSUOLO  SPEZIA  TORINO  UDINESE
# 1          1     1          1         1       1       1        1
# 3         20     5         13         7      13      18        9
# 15        16     2         15         6      18      14       12
# 6         20     5         13         7      13      18       10
# 16         5     1         14        10      19       5       14
# 14        17     1         14         5      19      13       12
# 2         16     3          9         2       9       9       20
# 4         18     6         15         4      10      10       17
# 7         18     6         15         4      11      11       17
# 9         15    13          4        11       2      11       20
# 8         13    12          5         7       3       5       20
# 18        13    18          7         5       1       8       20
# 5         11    10         13         5       9       1       19
# 12         7     1          7         1      13       4        7
# 17        12    16          6         3       1       7       20
# 13         8     2          4         2      14       4        8
# 0          2    19          8         9       1      14        2
# 11         8     8         14         2      19      12       19
# 10         1    16          3         9       4      12        6
#
# [19 rows x 21 columns]

# %%
Squad_Shooting_Rankings.reset_index(inplace = True,
                                    drop = True)
Squad_Shooting_Rankings
# Out:
# Squad        SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  \
# 0              90s         1          1        1         1        1
# 1               Sh         6         16        4        10       16
# 2             npxG         3         16        8        10       19
# 3        Sh_per_90         6         16        4        11       16
# 4      npxG_per_Sh         5         10       17         5       19
# 5               xG         4         16       10         8       18
# 6              Gls         1         14        9         7       18
# 7              SoT         3         15        2         8       20
# 8       SoT_per_90         3         15        2         9       20
# 9        G_per_SoT         3          4       17         1       18
# 10        G_per_Sh         1          3       17         1       19
# 11         np_G_xG         2          6       10         4       17
# 12         SoT_Pct         4          8        2         7       20
# 13              PK         7         13       13         7        4
# 14            G_xG         2          7       10         4       17
# 15           PKatt         8          8       14         8        4
# 16            # Pl         9         19       14        14        6
# 17              FK         4          8        2         4       12
# 18            Dist         8          9        6        15        2
#
# Squad  FIORENTINA  GENOA  HELLAS VERONA  INTER  ...  LAZIO  MILAN  NAPOLI  \
# 0               1      1              1      1  ...      1      1      19
# 1              11     19             15      1  ...      8      3       2
# 2               8     19             13      1  ...     11      4       5
# 3              12     19             15      2  ...      9      3       1
# 4               3     17             10      3  ...     10      5      14
# 5              10     20             15      3  ...      9      2       7
# 6              14     17             18      4  ...      9      4       4
# 7              10     19              9      4  ...     10      7       1
# 8              11     19             10      4  ...     11      7       1
# 9               6     10             18      6  ...      6     15      13
# 10              7     13             18      7  ...     13     13       7
# 11             13      8             19     12  ...     11     16       3
# 12             15     17              6     12  ...     18     16       3
# 13             13     13             13     13  ...      7      1      13
# 14             15      9             19     13  ...     11     18       5
# 15             14     14             14     14  ...      8      1      14
# 16              9      2              2     14  ...      6      9      14
# 17              8     16             16     16  ...     14      1       4
# 18             19      4             20     18  ...      9     17      12
#
# Squad  PARMA  ROMA  SAMPDORIA  SASSUOLO  SPEZIA  TORINO  UDINESE
# 0          1     1          1         1       1       1        1
# 1         20     5         13         7      13      18        9
# 2         16     2         15         6      18      14       12
# 3         20     5         13         7      13      18       10
# 4          5     1         14        10      19       5       14
# 5         17     1         14         5      19      13       12
# 6         16     3          9         2       9       9       20
# 7         18     6         15         4      10      10       17
# 8         18     6         15         4      11      11       17
# 9         15    13          4        11       2      11       20
# 10        13    12          5         7       3       5       20
# 11        13    18          7         5       1       8       20
# 12        11    10         13         5       9       1       19
# 13         7     1          7         1      13       4        7
# 14        12    16          6         3       1       7       20
# 15         8     2          4         2      14       4        8
# 16         2    19          8         9       1      14        2
# 17         8     8         14         2      19      12       19
# 18         1    16          3         9       4      12        6
#
# [19 rows x 21 columns]

# %%
Inter_Rankings_df = (
                     Squad_Shooting_Rankings[['SQUAD',
                                              'INTER']]
                     .rename(
                             columns = {
                                        'SQUAD' : 'Shooting_Variable'
                                       }
# renamed column input order ~~~~~~~~> {'OLD' : 'NEW'}
                            )
                     .set_index(
                                'Shooting_Variable'
                               )
                    )
Inter_Rankings_df
# Out:
# Squad              INTER
# Shooting_Variable
# 90s                    1
# Sh                     1
# npxG                   1
# Sh_per_90              2
# npxG_per_Sh            3
# xG                     3
# Gls                    4
# SoT                    4
# SoT_per_90             4
# G_per_SoT              6
# G_per_Sh               7
# np_G_xG               12
# SoT_Pct               12
# PK                    13
# G_xG                  13
# PKatt                 14
# # Pl                  14
# FK                    16
# Dist                  18

# %%
sns.set_context('talk')

Inter_Rankings_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Inter_Ranking_Value_Counts = (
                              Inter_Rankings_df[
                                                'INTER'
                                               ]
                              .value_counts()
                              
                              .reset_index(
                                           name = 'Distinct_Variable_Count'
                                          )
                              .rename(
                                      columns = {
                                                 'index':'Shooting_Stat_Rank'
                                                }
                                     )
                              .sort_values(
                                           'Shooting_Stat_Rank'
                                          )
                             )
Inter_Ranking_Value_Counts
# Out:
#     Shooting_Stat_Rank  Distinct_Variable_Count
# 1                    1                        3
# 10                   2                        1
# 5                    3                        2
# 0                    4                        3
# 9                    6                        1
# 8                    7                        1
# 4                   12                        2
# 3                   13                        2
# 2                   14                        2
# 7                   16                        1
# 6                   18                        1

# %%
#TACKLING_by_PITCH_THIRD_df = (#Defensive_Action_Ranking_df[  # 'Squad' #~~~> index is...
                                                             #  ...automatically included
#                              Defensive_Actions_df[
#                                                   [
#                                                    'Squad',
                                                    
#                                                    'Tkl_Def3rd',
#                                                    'Tkl_Mid3rd',
#                                                    'Tkl_Att3rd'
#                                                   ]
#                                                  ]
#                              .sort_values(
#                                           'Tkl_Att3rd',
#                                           ascending = False
#                                          )
#                              .set_index(
#                                         'Squad'
#                                        )
#                             )
#TACKLING_by_PITCH_THIRD_df

# %% [markdown]
# PRESSING_by_PITCH_THIRD_df = (
#                               Defensive_Actions_df[[
#                                                     'Squad',
#                                                     'Press_Def3rd',
#                                                     'Press_Mid3rd',
#                                                     'Press_Att3rd'
#                                                    ]]
#                               .sort_values(
#                                            'Press_Att3rd',
#                                            ascending = False
#                                           )
#                               .set_index(
#                                          'Squad'
#                                         )
#                              )
# PRESSING_by_PITCH_THIRD_df

# %% [markdown]
# ## PART (3) — actually PLOTTING the data

# %% [markdown]
# sns.set_context(
#                 'poster',
#                 font_scale = 2.4
#                )
#
# fig, ax = plt.subplots(
#                        figsize = (
#                                   120,  # horizontal WIDTH
#                                   60    # vertical HEIGHT
#                                  )
#                       )
#
# #### set the positions and width for the bars
#
# pos = list(range(
#                  len(
#                      TACKLING_by_PITCH_THIRD_df['Tkl_Def3rd']
#                     )
#                 ))
# width = 0.25
#
#
# #### create the bars, in position pos, for Y-axis Variable #1
# plt.bar(
#         pos,
#
#         TACKLING_by_PITCH_THIRD_df['Tkl_Def3rd'],
#
#         width,
#         #alpha = 0.9,
#         color = 'purple'   #'#EE3224'
#        )
#
# #### create bars, in position pos + width buffer, for Y-axis Variable #2
# plt.bar([
#          (p + width
#          ) for p in pos
#         ],
#
#         TACKLING_by_PITCH_THIRD_df['Tkl_Mid3rd'],
#
#         width,
#         #alpha = 0.9,
#         color = 'green'     # 'yellow'   # 'lightblue'   #'#F78F1E'
#        )
#
# #### create bars, in position pos + width buffer, for Y-axis Variable #3
# plt.bar([
#          (p + width*2
#          ) for p in pos
#         ],
#
#         TACKLING_by_PITCH_THIRD_df['Tkl_Att3rd'],
#
#         width,
#         alpha = 0.8,
#         color = 'orange'   #'#FFC222'
#        )
#
# #ax.set_title('Test', fontsize = 60)
# plt.title(
#           'TACKLING - Team Totals per Third of the Pitch',
#           fontsize = 100,
#           color = 'lightblue'    # 'yellow'    # 'goldenrod'
#          )
#
# #ax.set_ylabel('Test Y label')
# #plt.ylabel('TACKLING - Totals per Third of the Pitch',fontsize = 70)
# #plt.xlabel('SQUADS', fontsize = 35, color = 'yellow')
#
# ax.set_xticks(
#               [
#                (p + width
#                ) for p in pos
#               ]                  #  , rot = 90
#              )
#
# ax.set_xticklabels(TACKLING_by_PITCH_THIRD_df.index)  # ['Squad'])
#
# plt.xlim(
#          min(pos) - (width * 1.5),
#          max(pos) + (width * 3.5)
#         )
#
# plt.ylim([
#           0,
#           (max(
#                TACKLING_by_PITCH_THIRD_df['Tkl_Def3rd']
#               ) * 1.03)
#          ])
#
# plt.legend(
#            [
#             'DEFENSIVE third',
#             'MIDDLE third',
#             'ATTACKING third'
#            ],
#            loc = 'upper right'
#           )
# plt.grid()
#
# plt.show()

# %% [markdown]
# sns.set_context(
#                 'poster',
#                 font_scale = 2.4
#                )
#
# fig, ax = plt.subplots(
#                        figsize = (
#                                   120,  # horizontal WIDTH
#                                   60    # vertical HEIGHT
#                                  )
#                       )
#
# pos = list(range(
#                  len(
#                      PRESSING_by_PITCH_THIRD_df['Press_Def3rd']
#                     )
#                 ))
# width = 0.25
#
#
# #### create the bars, in position pos, for Y-axis Variable #1
# plt.bar(
#         pos,
#
#         PRESSING_by_PITCH_THIRD_df['Press_Def3rd'],
#
#         width, #alpha = 0.9,
#         color = 'purple'
#        )
#
# #### create bars, in position pos + width buffer, for Y-axis Variable #2
# plt.bar([
#          (p + width
#          ) for p in pos
#         ],
#
#         PRESSING_by_PITCH_THIRD_df['Press_Mid3rd'],
#
#         width, #alpha = 0.9,
#         color = 'green'
#        )
#
# #### create bars, in position pos + width buffer, for Y-axis Variable #3
# plt.bar([
#          (p + width*2
#          ) for p in pos
#         ],
#
#         PRESSING_by_PITCH_THIRD_df['Press_Att3rd'],
#
#         width,
#         alpha = 0.8,
#         color = 'orange'
#        )
#
# plt.title(
#           'PRESSING - Team Totals per Third of the Pitch',
#           fontsize = 100,
#           color = 'lightblue'    # 'yellow'    # 'goldenrod'
#          )
#
# ax.set_xticks(
#               [
#                (p + width
#                ) for p in pos
#               ]                  #  , rot = 90
#              )
#
# ax.set_xticklabels(
#                    PRESSING_by_PITCH_THIRD_df.index
#                   )                       # ['Squad'])
#
# plt.xlim(
#          min(pos) - (width * 1.5),
#          max(pos) + (width * 3.5)
#         )
#
# plt.ylim([
#           0,
#           (max(
#                PRESSING_by_PITCH_THIRD_df['Press_Mid3rd']
#               ) * 1.03)
#          ])
#
# plt.legend(
#            [
#             'DEFENSIVE third',
#             'MIDDLE third',
#             'ATTACKING third'
#            ],
#            loc = 'upper right'
#           )
# plt.grid()
#
# plt.show()

# %%
sns.set_context(
                'notebook',
                font_scale = 1.8
               )

ax = sns.lmplot(x = 'Sh',                       # horizontal axis
                y = 'npxG',                       # vertical axis
                
                data = Squad_Shooting_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 18,              
                aspect = 1.2      #  dimension of x-axis (sets width)
               )

x_col_min = Squad_Shooting_df['Sh'].min()
x_col_max = Squad_Shooting_df['Sh'].max()

y_col_min = Squad_Shooting_df['npxG'].min()
y_col_max = Squad_Shooting_df['npxG'].max()

plt.xlim((x_col_min * 0.95),
         (x_col_max * 1.005)
        )
plt.ylim((y_col_min * 0.9),
         (y_col_max * 1.025)
        )


plt.title('Serie A (20/21) - first seven matches - TOTAL SHOTS vs NON-Penalty EXPECTED GOALS (npxG)',
          fontsize = 25,
          color = 'goldenrod'
         )

plt.xlabel('TOTAL SHOT ATTEMPTS',
           fontsize = 30,
           color = 'yellow'
          )
plt.ylabel('NON-PENALTY EXPECTED GOALS (npxG)',
           fontsize = 30,
           color = 'yellow'
          )


point_labels = [plt.text(Squad_Shooting_df.Sh[i],
                         Squad_Shooting_df.npxG[i],
                         
                         Squad_Shooting_df.Squad[i],
                         fontsize = 25
                         
                        ) for i in range(len(Squad_Shooting_df.Squad))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 6
