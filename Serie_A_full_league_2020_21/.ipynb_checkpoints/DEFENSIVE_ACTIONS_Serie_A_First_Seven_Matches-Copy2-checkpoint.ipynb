# %% [markdown]
# # Analysis — Serie A (20/21 season) — Data after Match Week 7

# %% [markdown]
# ## DataFrame #2  —  Squad DEFENSIVE ACTIONS

# %%
import pandas as pd
import numpy as np

# %%
from adjustText import adjust_text

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
#plt.style.use('seaborn-whitegrid')
#plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')

#fig, ax = plt.subplots()

# %%
#plt.style.use(['fivethirtyeight','dark_background'])
#plt.style.use(['seaborn','dark_background'])
#plt.style.use(['ggplot','dark_background'])
#plt.style.use(['seaborn-whitegrid','dark_background'])
plt.style.use(['bmh','dark_background'])


#fig, ax = plt.subplots()

# %%
#plt.margins(x = 5, y = 50)

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

# %%
sns.set_context('paper',
                font_scale = 1.2)

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ## PART (1) — LOAD into DataFrame(s)

# %%
Defensive_Actions_df = pd.read_csv("Squad_Defensive_Actions.csv")

Defensive_Actions_df
# Out:
#             Squad  # Pl  90s  Tkl  TklW  Tkl_Def3rd  Tkl_Mid3rd  Tkl_Att3rd  \
# 0        Atalanta    23  7.0  132    76          48          63          21
# 1       Benevento    21  7.0  104    55          53          39          12
# 2         Bologna    22  7.0  115    71          49          52          14
# 3        Cagliari    22  7.0  131    73          53          57          21
# 4         Crotone    25  7.0  138    91          71          44          23
# 5      Fiorentina    23  7.0   92    57          43          40           9
# 6           Genoa    26  7.0  120    75          57          47          16
# 7   Hellas Verona    26  7.0   86    55          37          44           5
# 8           Inter    22  7.0  106    68          34          48          24
# 9        Juventus    23  6.0   95    65          54          37           4
# 10          Lazio    25  7.0  121    77          49          55          17
# ...

# %% [markdown]
# Columns list:
#
# 'Squad',
# '# Pl',
# '90s',
# 'Tkl',
# 'TklW',
# 'Tkl_Def3rd',
# 'Tkl_Mid3rd',
# 'Tkl_Att3rd',
# 'Tkl_vs_Drib',
# 'Att_vs_Drib',
# 'Tkl_Pct_vs_Drib',
# 'Past_vs_Drib',
# 'Press',
# 'Press_Succ',
# 'Press_Succ_Pct',
# 'Press_Def3rd',
# 'Press_Mid3rd',
# 'Press_Att3rd',
# 'Blocks',
# 'Block_Sh',
# 'ShSv',
# 'Block_Pass',
# 'Int',
# 'Tkl_plus_Int',
# 'Clr',
# 'Err'

# %%
columns_list = list(Defensive_Actions_df.columns)

#del columns_list[0:2]
#columns_list.remove('Squad')
#columns_list.remove('# Pl')
#columns_list.remove('90s')

columns_list
# Out:
# ['Squad',
#  '# Pl',
#  '90s',
#  'Tkl',
#  'TklW',
#  'Tkl_Def3rd',
#  'Tkl_Mid3rd',
#  'Tkl_Att3rd',
#  'Tkl_vs_Drib',
#  'Att_vs_Drib',
#  'Tkl_Pct_vs_Drib',
#  'Past_vs_Drib',
#  'Press',
#  'Press_Succ',
#  'Press_Succ_Pct',
#  'Press_Def3rd',
#  'Press_Mid3rd',
#  'Press_Att3rd',
#  'Blocks',
#  'Block_Sh',
#  'ShSv',
#  'Block_Pass',
#  'Int',
#  'Tkl_plus_Int',
#  'Clr',
#  'Err']

# %% [markdown]
# ## PART (2) — identify RANKINGS per column

# %% [markdown]
# ### Start by creating a separate DataFrame to store each club's ranking per column

# %%
Defensive_Action_RANKINGS = Defensive_Actions_df[['Squad', '90s']]

Defensive_Action_RANKINGS.head(5)
# Out:
#        Squad  90s
# 0   Atalanta  7.0
# 1  Benevento  7.0
# 2    Bologna  7.0
# 3   Cagliari  7.0
# 4    Crotone  7.0

# %%
Defensive_Action_RANKINGS['SQUAD'] = list(map(str.upper,
                                              Defensive_Actions_df['Squad']))

Defensive_Action_RANKINGS.head(5)
# Out:
# <ipython-input-13-03068a6821aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Defensive_Action_RANKINGS['SQUAD'] = list(map(str.upper,
#        Squad  90s      SQUAD
# 0   Atalanta  7.0   ATALANTA
# 1  Benevento  7.0  BENEVENTO
# 2    Bologna  7.0    BOLOGNA
# 3   Cagliari  7.0   CAGLIARI
# 4    Crotone  7.0    CROTONE

# %%
Defensive_Action_RANKINGS['Tkl'] = Defensive_Actions_df['Tkl'].rank(ascending = 0,
                                                                    #  0 = 'False'
                                                                    method = 'min')

Defensive_Action_RANKINGS.head(10)
# Out:
# <ipython-input-14-ce9e0200240a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Defensive_Action_RANKINGS['Tkl'] = Defensive_Actions_df['Tkl'].rank(ascending = 0,
#            Squad  90s          SQUAD   Tkl
# 0       Atalanta  7.0       ATALANTA   2.0
# 1      Benevento  7.0      BENEVENTO  17.0
# 2        Bologna  7.0        BOLOGNA  11.0
# 3       Cagliari  7.0       CAGLIARI   3.0
# 4        Crotone  7.0        CROTONE   1.0
# 5     Fiorentina  7.0     FIORENTINA  19.0
# 6          Genoa  7.0          GENOA   7.0
# 7  Hellas Verona  7.0  HELLAS VERONA  20.0
# 8          Inter  7.0          INTER  15.0
# 9       Juventus  6.0       JUVENTUS  18.0

# %%
#Defensive_Action_RANKINGS = Defensive_Action_RANKINGS.sort_values('Tkl')

Defensive_Action_RANKINGS = Defensive_Action_RANKINGS[['SQUAD',
                                                       'Tkl']].sort_values('Tkl')

Defensive_Action_RANKINGS
# Out:
#             SQUAD   Tkl
# 4         CROTONE   1.0
# 0        ATALANTA   2.0
# 3        CAGLIARI   3.0
# 16       SASSUOLO   4.0
# 19        UDINESE   5.0
# 10          LAZIO   6.0
# 6           GENOA   7.0
# 13          PARMA   7.0
# 18         TORINO   9.0
# 11          MILAN   9.0
# 2         BOLOGNA  11.0
# 12         NAPOLI  12.0
# 17         SPEZIA  12.0
# 15      SAMPDORIA  14.0
# 8           INTER  15.0
# 14           ROMA  16.0
# 1       BENEVENTO  17.0
# 9        JUVENTUS  18.0
# 5      FIORENTINA  19.0
# 7   HELLAS VERONA  20.0

# %%
#Defensive_Action_Ranking_df = Defensive_Actions_df.apply(rank(ascending = 0,
#                                                              method = 'min'),
#                                                         axis=0,
#                                                         result_type='broadcast')
#Defensive_Action_Ranking_df


#  NameError: name 'rank' is not defined

# %%
Defensive_Action_Ranking_df = Defensive_Actions_df.rank(ascending = 0,
                                                        #  0 = 'False'
                                                        method = 'min')

Defensive_Action_Ranking_df['Squad'] = Defensive_Actions_df['Squad']


Defensive_Action_Ranking_df
# Out:
#             Squad  # Pl   90s   Tkl  TklW  Tkl_Def3rd  Tkl_Mid3rd  Tkl_Att3rd  \
# 0        Atalanta   9.0   1.0   2.0   5.0        15.0         1.0         3.0
# 1       Benevento  19.0   1.0  17.0  19.0        10.0        18.0        14.0
# 2         Bologna  14.0   1.0  11.0  12.0        13.0         5.0        10.0
# 3        Cagliari  14.0   1.0   3.0  10.0        10.0         2.0         3.0
# 4         Crotone   6.0   1.0   1.0   1.0         1.0        13.0         2.0
# 5      Fiorentina   9.0   1.0  19.0  18.0        17.0        17.0        16.0
# 6           Genoa   2.0   1.0   7.0   8.0         7.0        12.0         7.0
# 7   Hellas Verona   2.0   1.0  20.0  19.0        19.0        13.0        19.0
# 8           Inter  14.0   1.0  15.0  16.0        20.0         9.0         1.0
# 9        Juventus   9.0  19.0  18.0  17.0         9.0        19.0        20.0
# 10          Lazio   6.0   1.0   6.0   4.0        13.0         3.0         6.0
# ...

# %%
#Inter_Ranks = list(Defensive_Action_Ranking_df[Defensive_Action_Ranking_df.Squad == 'Inter'])

Inter_Ranks = Defensive_Action_Ranking_df[Defensive_Action_Ranking_df.Squad == 'Inter']

Inter_Ranks

# Inter_Rankings_Df = pd.DataFrame( )
# Out:
#    Squad  # Pl  90s   Tkl  TklW  Tkl_Def3rd  Tkl_Mid3rd  Tkl_Att3rd  \
# 8  Inter  14.0  1.0  15.0  16.0        20.0         9.0         1.0
#
#    Tkl_vs_Drib  Att_vs_Drib  ...  Press_Mid3rd  Press_Att3rd  Blocks  \
# 8          2.0         13.0  ...          12.0           3.0    19.0
#
#    Block_Sh  ShSv  Block_Pass   Int  Tkl_plus_Int   Clr   Err
# 8      20.0   5.0        19.0  18.0          17.0  19.0  12.0
#
# [1 rows x 26 columns]

# %% [markdown]
# ## PART (3) — actually PLOTTING the data

# %% [markdown]
# ### Scatterplot — Total PRESSURES vs Pressure SUCCESS RATE (all Serie A teams)

# %%
sns.set_context('paper',
                #font_scale = 2
                font_scale = 1.75)

#plt.margins(0.5, 0.5)


ax = sns.lmplot('Press',                       # horizontal axis
                'Press_Succ_Pct',                  # vertical axis
                
                data = Defensive_Actions_df,      # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.3      #  dimension of x-axis (sets width)
               )

#plt.margins(x = 50, y = 50)
#ax.margins(x = 0.5,y = 0.5)
#plt.margins(0.5, 0.5)



x_col_min = Defensive_Actions_df['Press'].min()
x_col_max = Defensive_Actions_df['Press'].max()

y_col_min = Defensive_Actions_df['Press_Succ_Pct'].min()
y_col_max = Defensive_Actions_df['Press_Succ_Pct'].max()

#plt.xlim((x_col_min - 1), (x_col_max + 1))
#plt.ylim((y_col_min - 1), (y_col_max + 1))

plt.xlim((x_col_min * 0.96), (x_col_max * 1.01))
plt.ylim((y_col_min * 0.97), (y_col_max * 1.03))


#  COLOR REFERENCE:
#    https://matplotlib.org/gallery/color/named_colors.html

plt.title('Serie A (20/21) first seven matches - PRESSURES - TOTAL vs SUCCESS RATE (%)',
          fontsize = 26,
          #color = 'limegreen'
          #color = 'lime'
          #color = 'springgreen'
          #color = 'palegreen'
          #color = 'lightgreen'
          #color = 'lightseagreen'
          #color = 'mediumseagreen'
          color = 'darkseagreen'
          #color = 'greenyellow'
          #color = 'mediumaquamarine'
         )

plt.xlabel('PRESSURES - TOTAL',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('PRESSURES - SUCCESS RATE (%)',
           fontsize = 25,
           color = 'yellow'
          )


point_labels = [plt.text(Defensive_Actions_df.Press[i],
                         Defensive_Actions_df.Press_Succ_Pct[i],
                         
                         Defensive_Actions_df.Squad[i],
                         fontsize = 18
                         
                        ) for i in range(len(Defensive_Actions_df.Squad))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6

# %% [markdown]
# plot_margin = 0.5
#
# x0, x1, y0, y1 = plt.axis()
#
# plt.axis((x0 - plot_margin,
#           x1 + plot_margin,
#           y0 - plot_margin,
#           y1 + plot_margin))

# %% [markdown]
# # NOTE TO SELF:
#
# Add in the "points" column from the league table,
#
# then use that to determine the scatter dot size for each team

# %% [markdown]
# ### Scatterplot — TACKLES in ATTACKING vs DEFENSIVE Third (all Serie A teams)

# %%
sns.set_context('paper',
                font_scale = 1.75)


ax = sns.lmplot('Tkl_Att3rd',                       # horizontal axis
                'Tkl_Def3rd',                  # vertical axis
                
                data = Defensive_Actions_df,      # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

x_col_min = Defensive_Actions_df['Tkl_Att3rd'].min()
x_col_max = Defensive_Actions_df['Tkl_Att3rd'].max()

y_col_min = Defensive_Actions_df['Tkl_Def3rd'].min()
y_col_max = Defensive_Actions_df['Tkl_Def3rd'].max()

#plt.xlim((x_col_min - 1), (x_col_max + 1))
#plt.ylim((y_col_min - 1), (y_col_max + 1))

plt.xlim((x_col_min * 0.92), (x_col_max * 1.1))
plt.ylim((y_col_min * 0.86), (y_col_max * 1.03))


plt.title('Serie A (20/21) first seven matches - TACKLES in ATTACKING vs DEFENSIVE Third',
          fontsize = 26,     #30,
          #color = 'yellow'
          #color = 'mediumseagreen'
          #color = 'silver'
          color = 'goldenrod'
         )
plt.xlabel('TACKLES in ATTACKING Third',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('TACKLES in DEFENSIVE Third',
           fontsize = 25,
           color = 'yellow'
          )


point_labels = [plt.text(Defensive_Actions_df.Tkl_Att3rd[i],
                         Defensive_Actions_df.Tkl_Def3rd[i],
                         
                         Defensive_Actions_df.Squad[i],
                         fontsize = 20
                         
                        ) for i in range(len(Defensive_Actions_df.Squad))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6

# %% [markdown]
# ### Scatterplot — TACKLES against DRIBBLES — TOTAL vs SUCCESS RATE (all Serie A teams)

# %%
sns.set_context('paper',
                font_scale = 1.75)


ax = sns.lmplot('Tkl_vs_Drib',                       # horizontal axis
                'Tkl_Pct_vs_Drib',                  # vertical axis
                
                data = Defensive_Actions_df,      # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

x_col_min = Defensive_Actions_df['Tkl_vs_Drib'].min()
x_col_max = Defensive_Actions_df['Tkl_vs_Drib'].max()

y_col_min = Defensive_Actions_df['Tkl_Pct_vs_Drib'].min()
y_col_max = Defensive_Actions_df['Tkl_Pct_vs_Drib'].max()

#plt.xlim((x_col_min - 1), (x_col_max + 1))
#plt.ylim((y_col_min - 1), (y_col_max + 1))

plt.xlim((x_col_min * 0.95), (x_col_max * 1.02))
plt.ylim((y_col_min * 0.925), (y_col_max * 1.035))


plt.title('Serie A (20/21) first seven matches - TACKLES against DRIBBLES - TOTAL vs SUCCESS RATE (%)',
          fontsize = 25,
          #color = 'yellow'
          #color = 'mediumseagreen'
          #color = 'goldenrod'
          color = 'darkgoldenrod'
         )
plt.xlabel('TACKLES against DRIBBLE ATTEMPTS - TOTAL',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('TACKLES against DRIBBLES - SUCCESS RATE (%)',
           fontsize = 25,
           color = 'yellow'
          )


point_labels = [plt.text(Defensive_Actions_df.Tkl_vs_Drib[i],
                         Defensive_Actions_df.Tkl_Pct_vs_Drib[i],
                         
                         Defensive_Actions_df.Squad[i],
                         fontsize = 20
                         
                        ) for i in range(len(Defensive_Actions_df.Squad))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6
