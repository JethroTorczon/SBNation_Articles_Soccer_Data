# %% [markdown]
# # Analysis - Serie A (20/21 season) - Data after Match Week 7

# %%
import pandas as pd
import numpy as np

# %%
from adjustText import adjust_text

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
#plt.style.use('seaborn-whitegrid')

plt.style.use('dark_background')

#plt.style.use('fivethirtyeight')

fig, ax = plt.subplots()

# %% [markdown]
# # DataFrame #1  -  League "TABLE" (standings)

# %% [markdown]
# ## (DF #1) -- PART (1) -- Load Essential Variables Into DataFrames

# %%
SerieA_table = pd.read_csv("Serie_A_table_after_7_matches.csv")

SerieA_table.head(3)
# Out:
#    Rk     Squad  MP  W  D  L  GF  GA  GDiff  Pts    xG  xGA  xGDiff  \
# 0   1     Milan   7  5  2  0  16   7      9   17  16.5  8.7     7.7
# 1   2  Sassuolo   7  4  3  0  18   9      9   15  13.1  9.9     3.2
# 2   3    Napoli   7  5  0  2  15   7      8   15  11.3  4.4     6.9
#
#    xGDiff/90     Last 5         Top Team Scorer            Goalkeeper
# 0       1.10  W W D W D  Zlatan Ibrahimović - 8  Gianluigi Donnarumma
# 1       0.46  W W D W D    Francesco Caputo - 5       Andrea Consigli
# 2       1.14  L W W L W      Hirving Lozano - 4          David Ospina

# %%
SerieA_table_df = SerieA_table.loc[:,
                                   'Rk':'xGDiff/90']
SerieA_table_df   # .head(3)
# Out:
#     Rk          Squad  MP  W  D  L  GF  GA  GDiff  Pts    xG   xGA  xGDiff  \
# 0    1          Milan   7  5  2  0  16   7      9   17  16.5   8.7     7.7
# 1    2       Sassuolo   7  4  3  0  18   9      9   15  13.1   9.9     3.2
# 2    3         Napoli   7  5  0  2  15   7      8   15  11.3   4.4     6.9
# 3    4           Roma   7  4  2  1  16  11      5   14  16.7   9.0     7.7
# 4    5       Juventus   7  3  4  0  15   6      9   13  11.9   7.0     4.8
# 5    6       Atalanta   7  4  1  2  18  14      4   13  13.4   9.6     3.9
# 6    7          Inter   7  3  3  1  16  11      5   12  14.9   9.1     5.8
# 7    8  Hellas Verona   7  3  3  1  10   5      5   12   8.2  12.0    -3.8
# 8    9          Lazio   7  3  2  2  11  13     -2   11  10.1  10.6    -0.5
# 9   10       Cagliari   7  3  1  3  14  15     -1   10  10.2  12.8    -2.6
# 10  11      Sampdoria   7  3  1  3  11  11      0   10   8.7  11.1    -2.4
# 11  12     Fiorentina   7  2  2  3  10  12     -2    8  10.0  11.6    -1.6
# 12  13         Spezia   7  2  2  3  11  15     -4    8   5.8  15.3    -9.5
# 13  14        Bologna   7  2  0  5  11  13     -2    6  10.0  10.4    -0.4
# 14  15      Benevento   7  2  0  5  10  20    -10    6   7.9  16.0    -8.1
# 15  16          Parma   7  1  3  3   8  13     -5    6   7.8   9.6    -1.9
# 16  17         Torino   7  1  2  4  12  16     -4    5   8.9  10.5    -1.6
# 17  18          Genoa   7  1  2  4   7  15     -8    5   5.4  10.1    -4.7
# 18  19        Udinese   7  1  1  5   6  11     -5    4   9.0   5.8     3.2
# 19  20        Crotone   7  0  2  5   6  17    -11    2   7.0  13.1    -6.1
#
#     xGDiff/90
# 0        1.10
# 1        0.46
# 2        1.14
# 3        1.10
# 4        0.80
# 5        0.55
# 6        0.83
# 7       -0.55
# 8       -0.07
# 9       -0.37
# 10      -0.34
# 11      -0.22
# 12      -1.35
# 13      -0.05
# 14      -1.16
# 15      -0.27
# 16      -0.22
# 17      -0.67
# 18       0.45
# 19      -0.87

# %%
#Table_Narrow_df = SerieA_table_df[['Rk',
#                                   'Pts',
#                                   'Squad',
#                                   'GF',
#                                   'GA']]
#Table_Narrow_df.head(7)

# %%
#Sorted_Narrow_Table = Table_Narrow_df.sort_values('GF',
#                                                  ascending = False)
#Sorted_Narrow_Table

# %% [markdown]
# ## (still DF #1) -- PART (2) -- defining FUNCTIONS

# %% [markdown]
# ### Before actually creating the plots themselves, it is helpful to first define functions that can be used for customizing the formatting of any graph type that will be used more than once

# %%
def label_scatter_point(x,
                        y,
                        val,   #  point labels' source column
                        ax     #  plt.gca()
                       ):
    
    a = pd.concat({'x': x,
                   'y': y,
                   'val': val},
                  
                  axis = 1    # I think this clarifies that these are COLUMNS, not rows)
                 )

    
    for i, point in a.iterrows():

        ax.text(point['x'] + .04,
                point['y'] + .15,  # PLUS to shift UP
                point['val']
               )

# %% [markdown]
# #### example input to run the "label_scatter_point" function:

# %% [markdown]
# label_scatter_point(
#
#                     SerieA_table_df.GF,
#
#                     SerieA_table_df.GA,
#
#                     SerieA_table_df.Squad,   # "Squad" column = point label source
#
#                     plt.gca()
#
#                    )

# %% [markdown]
# def test_df_col_names_input(df_name,
#                             x_col_name,
#                             y_col_name,
#                             point_labels_col
#                            ):
#
#     test_df = df_name
#     # test_df.head(5)    # no error, but doesn't actually produce output
#
#     #
#
#     test_list_X = df_name.x_col_name
#
#     for each_val in len(test_list_X):
#         print(test_list_X[each_val])
#
#     # return...
#
#
# ##### AttributeError: 'DataFrame' object has no attribute 'x_col_name'

# %% [markdown]
# test_df_col_names_input(SerieA_table_df,
#                         'GF',
#                         'GA',
#                         'Squad'
#                        )
#
# ##### AttributeError: 'DataFrame' object has no attribute 'x_col_name'

# %% [markdown]
# ## (still DF #1) -- PART (3) -- actually PLOTTING the data

# %% [markdown]
# ## Scatterplot - Goals FOR vs Goals AGAINST (all Serie A teams)

# %%
ax = sns.lmplot('GF',                       # horizontal axis
                'GA',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

#plt.margins(x = 2.5, y = 1)
#plt.margins(x = 15, y = 5)


x_col_min = SerieA_table_df['GF'].min()
x_col_max = SerieA_table_df['GF'].max()

y_col_min = SerieA_table_df['GA'].min()
y_col_max = SerieA_table_df['GA'].max()

plt.xlim((x_col_min - 1), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 1))


plt.title('Serie A (20/21) - first seven matches - Goals FOR vs AGAINST',
          fontsize = 40
         )
plt.xlabel('Goals FOR',
           fontsize = 30
          )
plt.ylabel('Goals AGAINST',
           fontsize = 30
          )


point_labels = [plt.text(SerieA_table_df.GF[i],
                         SerieA_table_df.GA[i],
                         
                         SerieA_table_df.Squad[i],
                         fontsize = 15
                         
                        ) for i in range(len(SerieA_table_df.GF))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 5

# %% [markdown]
# ## Scatterplot - EXPECTED Goals FOR vs EXPECTED Goals AGAINST

# %%
ax = sns.lmplot('xG',                       # horizontal axis
                'xGA',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 10,              
                aspect = 1.3      #  dimension of x-axis (sets width)
               )

#ax.margins(x = 1.5, y = 0.1)
plt.margins(x = 2.5, y = 1)


x_col_min = SerieA_table_df['xG'].min()
x_col_max = SerieA_table_df['xG'].max()

y_col_min = SerieA_table_df['xGA'].min()
y_col_max = SerieA_table_df['xGA'].max()

plt.xlim((x_col_min - 1), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 1))


plt.title('Serie A (20/21) - first seven matches - xG vs xGA',
          fontsize = 40
         )
plt.xlabel('EXPECTED Goals FOR',
           fontsize = 25
          )
plt.ylabel('EXPECTED Goals AGAINST',
           fontsize = 15
          )


point_labels = [plt.text(SerieA_table_df.xG[i],
                         SerieA_table_df.xGA[i],
                         SerieA_table_df.Squad[i]
                        ) for i in range(len(SerieA_table_df.xG))]

adjust_text(point_labels)
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6

# %%
ax = sns.lmplot('xG',                       # horizontal axis
                'xGA',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

#plt.margins(x = 2.5, y = 1)
#plt.margins(x = 15, y = 5)


x_col_min = SerieA_table_df['xG'].min()
x_col_max = SerieA_table_df['xG'].max()

y_col_min = SerieA_table_df['xGA'].min()
y_col_max = SerieA_table_df['xGA'].max()

plt.xlim((x_col_min - 1), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 1))


plt.title('Serie A (20/21) - first seven matches - xG vs xGA',
          fontsize = 40
         )
plt.xlabel('xG - EXPECTED Goals FOR',
           fontsize = 30
          )
plt.ylabel('xGA - EXPECTED Goals AGAINST',
           fontsize = 30
          )


point_labels = [plt.text(SerieA_table_df.xG[i],
                         SerieA_table_df.xGA[i],
                         
                         SerieA_table_df.Squad[i],
                         fontsize = 15
                         
                        ) for i in range(len(SerieA_table_df.xG))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 6
