# %% [markdown]
# # Analysis — Serie A (20/21 season)
#
# ### Data for each TEAM in the top Italian league after Match Week 7
#
# ### FBref.com — source DataFrame:
#
# # "LEAGUE TABLE"
#
# (a.k.a. "standings" in U.S. terms)

# %%
import pandas as pd
import numpy as np

# %%
from adjustText import adjust_text

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
#plt.style.use('seaborn-whitegrid')
#plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')

#fig, ax = plt.subplots()

# %%
#plt.style.use(['fivethirtyeight','dark_background'])
#plt.style.use(['seaborn','dark_background'])
#plt.style.use(['ggplot','dark_background'])
#plt.style.use(['seaborn-whitegrid','dark_background'])

plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

sns.set_context(
                'notebook',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %%
import os.path
#~~~~~~~~~~~~~~~~~~~~~~
from PIL import Image
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

image_folder_path = ('~/SBNation_Articles_Soccer_Data/' +
                     'Logo_Pictures_for_Data_Sources/')

logos_flat_path = (image_folder_path +
                   'logos_flat_small.png')

open_flat_logos = os.path.expanduser(logos_flat_path)

logos_flat_small = Image.open(open_flat_logos)

logos_flat_small
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=233x25 at 0x7FF8C794D4C0>

# %% [markdown]
# ## PART (1) — LOAD into DataFrame(s)

# %%
SerieA_table = pd.read_csv("Serie_A_table_after_7_matches.csv")

SerieA_table_df = SerieA_table.loc[:,
                                   'Rk':'xGDiff/90']
SerieA_table_df
# Out:
#     Rk          Squad  MP  W  D  L  GF  GA  GDiff  Pts    xG   xGA  xGDiff  \
# 0    1          Milan   7  5  2  0  16   7      9   17  16.5   8.7     7.7
# 1    2       Sassuolo   7  4  3  0  18   9      9   15  13.1   9.9     3.2
# 2    3         Napoli   7  5  0  2  15   7      8   15  11.3   4.4     6.9
# 3    4           Roma   7  4  2  1  16  11      5   14  16.7   9.0     7.7
# 4    5       Juventus   7  3  4  0  15   6      9   13  11.9   7.0     4.8
# 5    6       Atalanta   7  4  1  2  18  14      4   13  13.4   9.6     3.9
# 6    7          Inter   7  3  3  1  16  11      5   12  14.9   9.1     5.8
# 7    8  Hellas Verona   7  3  3  1  10   5      5   12   8.2  12.0    -3.8
# 8    9          Lazio   7  3  2  2  11  13     -2   11  10.1  10.6    -0.5
# 9   10       Cagliari   7  3  1  3  14  15     -1   10  10.2  12.8    -2.6
# 10  11      Sampdoria   7  3  1  3  11  11      0   10   8.7  11.1    -2.4
# ...

# %% [markdown]
# ### Columns list:

# %%
columns_list = list(
                    SerieA_table_df.columns
                   )
columns_list
# Out:
# ['Rk',
#  'Squad',
#  'MP',
#  'W',
#  'D',
#  'L',
#  'GF',
#  'GA',
#  'GDiff',
#  'Pts',
#  'xG',
#  'xGA',
#  'xGDiff',
#  'xGDiff/90']

# %% [markdown]
# ## PART (2) — identify RANKINGS per column

# %%
SerieA_table_Ranking_df = SerieA_table_df.rank(ascending = 0,
                                         #      '0' = 'False'
                                               method = 'min'
                                              )

SerieA_table_Ranking_df = SerieA_table_Ranking_df.astype(int)


SerieA_table_Ranking_df['Squad'] = list(map(str.upper,
                                            SerieA_table_df['Squad']
                                           )
                                       )
SerieA_table_Ranking_df
# Out:
#     Rk          Squad  MP   W   D   L  GF  GA  GDiff  Pts  xG  xGA  xGDiff  \
# 0   20          MILAN   1   1   6  18   3  17      1    1   2   17       1
# 1   19       SASSUOLO   1   3   2  18   1  16      1    2   5   12       7
# 2   18         NAPOLI   1   1  18  12   6  17      4    2   7   20       3
# 3   17           ROMA   1   3   6  15   3  12      5    4   1   16       1
# 4   16       JUVENTUS   1   6   1  18   6  19      1    5   6   18       5
# 5   15       ATALANTA   1   3  14  12   1   7      8    5   4   13       6
# 6   14          INTER   1   6   2  15   3  12      5    7   3   15       4
# 7   13  HELLAS VERONA   1   6   2  15  14  20      5    7  15    5      16
# 8   12          LAZIO   1   6   6  12  10   8     11    9   9    8      10
# 9   11       CAGLIARI   1   6  14   7   8   4     10   10   8    4      15
# 10  10      SAMPDORIA   1   6  14   7  10  12      9   10  14    7      14
# ...

# %%
SerieA_table_Ranking_df.set_index('Squad',
                                  inplace = True)
SerieA_table_Ranking_df
# Out:
#                Rk  MP   W   D   L  GF  GA  GDiff  Pts  xG  xGA  xGDiff  \
# Squad
# MILAN          20   1   1   6  18   3  17      1    1   2   17       1
# SASSUOLO       19   1   3   2  18   1  16      1    2   5   12       7
# NAPOLI         18   1   1  18  12   6  17      4    2   7   20       3
# ROMA           17   1   3   6  15   3  12      5    4   1   16       1
# JUVENTUS       16   1   6   1  18   6  19      1    5   6   18       5
# ATALANTA       15   1   3  14  12   1   7      8    5   4   13       6
# INTER          14   1   6   2  15   3  12      5    7   3   15       4
# HELLAS VERONA  13   1   6   2  15  14  20      5    7  15    5      16
# LAZIO          12   1   6   6  12  10   8     11    9   9    8      10
# CAGLIARI       11   1   6  14   7   8   4     10   10   8    4      15
# SAMPDORIA      10   1   6  14   7  10  12      9   10  14    7      14
# FIORENTINA      9   1  12   6   7  14  11     11   12  10    6      11
# ...

# %%
SerieA_table_Ranks_Transposed = SerieA_table_Ranking_df.transpose()

SerieA_table_Ranks_Transposed
# Out:
# Squad      MILAN  SASSUOLO  NAPOLI  ROMA  JUVENTUS  ATALANTA  INTER  \
# Rk            20        19      18    17        16        15     14
# MP             1         1       1     1         1         1      1
# W              1         3       1     3         6         3      6
# D              6         2      18     6         1        14      2
# L             18        18      12    15        18        12     15
# GF             3         1       6     3         6         1      3
# GA            17        16      17    12        19         7     12
# GDiff          1         1       4     5         1         8      5
# Pts            1         2       2     4         5         5      7
# xG             2         5       7     1         6         4      3
# xGA           17        12      20    16        18        13     15
# xGDiff         1         7       3     1         5         6      4
# xGDiff/90      2         7       1     2         5         6      4
#
# ...

# %%
SerieA_table_Ranks_Transposed.reset_index(inplace = True
                                         )
SerieA_table_Ranks_Transposed.rename(columns = {'index':'SQUAD'
                                               },
                                     # order = {
#                                                'OLD' : 'NEW'
#                                              }
                                     inplace = True
                                    )
SerieA_table_Ranks_Transposed
# Out:
# Squad      SQUAD  MILAN  SASSUOLO  NAPOLI  ROMA  JUVENTUS  ATALANTA  INTER  \
# 0             Rk     20        19      18    17        16        15     14
# 1             MP      1         1       1     1         1         1      1
# 2              W      1         3       1     3         6         3      6
# 3              D      6         2      18     6         1        14      2
# 4              L     18        18      12    15        18        12     15
# 5             GF      3         1       6     3         6         1      3
# 6             GA     17        16      17    12        19         7     12
# 7          GDiff      1         1       4     5         1         8      5
# 8            Pts      1         2       2     4         5         5      7
# 9             xG      2         5       7     1         6         4      3
# 10           xGA     17        12      20    16        18        13     15
# ...

# %%
SerieA_table_Rankings = SerieA_table_Ranks_Transposed.sort_values('INTER')
SerieA_table_Rankings
# Out:
# Squad      SQUAD  MILAN  SASSUOLO  NAPOLI  ROMA  JUVENTUS  ATALANTA  INTER  \
# 1             MP      1         1       1     1         1         1      1
# 3              D      6         2      18     6         1        14      2
# 5             GF      3         1       6     3         6         1      3
# 9             xG      2         5       7     1         6         4      3
# 11        xGDiff      1         7       3     1         5         6      4
# 12     xGDiff/90      2         7       1     2         5         6      4
# 7          GDiff      1         1       4     5         1         8      5
# 2              W      1         3       1     3         6         3      6
# 8            Pts      1         2       2     4         5         5      7
# 6             GA     17        16      17    12        19         7     12
# 0             Rk     20        19      18    17        16        15     14
# ...

# %%
SerieA_table_Rankings.reset_index(inplace = True,
                                  drop = True)
SerieA_table_Rankings
# Out:
# Squad      SQUAD  MILAN  SASSUOLO  NAPOLI  ROMA  JUVENTUS  ATALANTA  INTER  \
# 0             MP      1         1       1     1         1         1      1
# 1              D      6         2      18     6         1        14      2
# 2             GF      3         1       6     3         6         1      3
# 3             xG      2         5       7     1         6         4      3
# 4         xGDiff      1         7       3     1         5         6      4
# 5      xGDiff/90      2         7       1     2         5         6      4
# 6          GDiff      1         1       4     5         1         8      5
# 7              W      1         3       1     3         6         3      6
# 8            Pts      1         2       2     4         5         5      7
# 9             GA     17        16      17    12        19         7     12
# 10            Rk     20        19      18    17        16        15     14
# ...

# %%
Inter_Rankings_df = (
                     SerieA_table_Rankings[['SQUAD',
                                            'INTER']]
                     .rename(
                             columns = {
                                        'SQUAD' : 'Defensive_Variable'
                                       }
# renamed column input order ~~~~~~~~> {'OLD' : 'NEW'}
                            )
                     .set_index(
                                'Defensive_Variable'
                               )
                    )
Inter_Rankings_df
# Out:
# Squad               INTER
# Defensive_Variable
# MP                      1
# D                       2
# GF                      3
# xG                      3
# xGDiff                  4
# xGDiff/90               4
# GDiff                   5
# W                       6
# Pts                     7
# GA                     12
# Rk                     14
# L                      15
# xGA                    15

# %%
sns.set_context('talk')

Inter_Rankings_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Inter_Ranking_Value_Counts = (
                              Inter_Rankings_df[
                                                'INTER'
                                               ]
                              .value_counts()
                              
                              .reset_index(
                                           name = 'Distinct_Variable_Count'
                                          )
                              .rename(
                                      columns = {
                                                 'index':'Standard_Stat_Rank'
                                                }
                                     )
                              .sort_values(
                                           'Standard_Stat_Rank'
                                          )
                             )
Inter_Ranking_Value_Counts
# Out:
#    Standard_Stat_Rank  Distinct_Variable_Count
# 9                   1                        1
# 8                   2                        1
# 2                   3                        2
# 1                   4                        2
# 7                   5                        1
# 6                   6                        1
# 5                   7                        1
# 4                  12                        1
# 3                  14                        1
# 0                  15                        2

# %% [markdown]
# ## PART (3) — actually PLOTTING the data

# %%
# identify the source time period in SUBTITLE:

subtitle = ' Serie A  (20/21)  data after  Match Week 7'


# duplicate that variable, except spread across 2 lines:

subtitle_2_lines = ('Serie A  (20/21 season)' +
                    '\n' +
                    'data after Match Week 7')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# attribute this work to "InterPool" specifically for S.O.M.:

prod_by_and_for = ('produced by \"InterPool\" for SB Nation\'s  ' +
                   '\n' +
                   'Inter Milan site: Serpents Of Madonnina ')

# %% [markdown]
# ## SCATTERPLOTS

# %%
ax = sns.lmplot(x = 'GF',                       # horizontal axis
                y = 'GA',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.margins(x = 2.5, y = 1)
#plt.margins(x = 15, y = 5)

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = SerieA_table_df['GF'].min()
x_col_max = SerieA_table_df['GF'].max()

y_col_min = SerieA_table_df['GA'].min()
y_col_max = SerieA_table_df['GA'].max()

plt.xlim((x_col_min - 1), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 1))

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('Goals FOR vs AGAINST - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('Goals - FOR vs AGAINST     ',
             
             x = 0.475,
             y = 1.01,
             
             fontsize = 29,
             
             color = 'yellow'
            )


# identify the source time period in SUBTITLE:

plt.title(
          subtitle_2_lines,
          
          loc = 'left',

          fontsize = 15,
          
          alpha = 0.9,
          
          style = 'italic',

          color = 'goldenrod'
         )


# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,
          
          alpha = 0.7,
          
          style = 'italic',
          
          color = 'lightblue'
         )
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Goals FOR',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('Goals AGAINST',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1065,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(SerieA_table_df.GF[i],
                         SerieA_table_df.GA[i],
                         
                         SerieA_table_df.Squad[i],
                         fontsize = 25
                         
                        ) for i in range(len(SerieA_table_df.GF))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 22

# %%
ax = sns.lmplot(x = 'xG',                       # horizontal axis
                y = 'xGA',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 13,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = SerieA_table_df['xG'].min()
x_col_max = SerieA_table_df['xG'].max()

y_col_min = SerieA_table_df['xGA'].min()
y_col_max = SerieA_table_df['xGA'].max()

plt.xlim((x_col_min - 1), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 1))

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('xG vs xGA - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('EXPECTED GOALS - xG vs xGA     ',
             
             x = 0.475,
             y = 1.01,
             
             fontsize = 29,
             
             color = 'yellow'
            )


# identify the source time period in SUBTITLE:

plt.title(
          subtitle_2_lines,
          
          loc = 'left',

          fontsize = 15,
          
          alpha = 0.9,
          
          style = 'italic',

          color = 'goldenrod'
         )


# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,
          
          alpha = 0.7,
          
          style = 'italic',
          
          color = 'lightblue'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('xG - EXPECTED Goals FOR',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('xGA - EXPECTED Goals AGAINST',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1075,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(SerieA_table_df.xG[i],
                         SerieA_table_df.xGA[i],
                         
                         SerieA_table_df.Squad[i],
                         fontsize = 25
                         
                        ) for i in range(len(SerieA_table_df.xG))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 6

# %%
ax = sns.lmplot(x = 'GF',                       # horizontal axis
                y = 'xG',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 16,              
                aspect = 1.3      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = SerieA_table_df['GF'].min()
x_col_max = SerieA_table_df['GF'].max()

y_col_min = SerieA_table_df['xG'].min()
y_col_max = SerieA_table_df['xG'].max()

plt.xlim((x_col_min - 0.5), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 0.5))

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('Goals FOR vs EXPECTED - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('Goals For - ACTUAL vs EXPECTED     ',
             
             x = 0.475,
             y = 1.01,
             
             fontsize = 29,
             
             color = 'yellow'
            )


# identify the source time period in SUBTITLE:

plt.title(
          subtitle_2_lines,
          
          loc = 'left',

          fontsize = 15,
          
          alpha = 0.9,
          
          style = 'italic',

          color = 'goldenrod'
         )


# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,
          
          alpha = 0.7,
          
          style = 'italic',
          
          color = 'lightblue'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Goals FOR',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('Goals EXPECTED (xG)',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1250,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(SerieA_table_df.GF[i],
                         SerieA_table_df.xG[i],
                         
                         SerieA_table_df.Squad[i],
                         fontsize = 25
                         
                        ) for i in range(len(SerieA_table_df.GF))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 34

# %%
ax = sns.lmplot(x = 'GA',                       # horizontal axis
                y = 'xGA',                       # vertical axis
                
                data = SerieA_table_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 16,              
                aspect = 1.3      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = SerieA_table_df['GA'].min()
x_col_max = SerieA_table_df['GA'].max()

y_col_min = SerieA_table_df['xGA'].min()
y_col_max = SerieA_table_df['xGA'].max()

plt.xlim((x_col_min - 0.5), (x_col_max + 1))
plt.ylim((y_col_min - 1), (y_col_max + 0.5))

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('Goals AGAINST vs EXPECTED - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('Goals Against - ACTUAL vs EXPECTED     ',
             
             x = 0.475,
             y = 1.01,
             
             fontsize = 29,
             
             color = 'yellow'
            )


# identify the source time period in SUBTITLE:

plt.title(
          subtitle_2_lines,
          
          loc = 'left',

          fontsize = 15,
          
          alpha = 0.9,
          
          style = 'italic',

          color = 'goldenrod'
         )


# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,
          
          alpha = 0.7,
          
          style = 'italic',
          
          color = 'lightblue'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Goals AGAINST',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('Goals AGAINST - EXPECTED (xGA)',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1250,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(SerieA_table_df.GA[i],
                         SerieA_table_df.xGA[i],
                         
                         SerieA_table_df.Squad[i],
                         fontsize = 25
                         
                        ) for i in range(len(SerieA_table_df.Squad))
               ]

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 6
