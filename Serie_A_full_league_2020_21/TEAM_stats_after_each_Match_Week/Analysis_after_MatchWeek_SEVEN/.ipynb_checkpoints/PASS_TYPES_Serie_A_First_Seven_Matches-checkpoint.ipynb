# %% [markdown]
# # Analysis — Serie A (20/21 season)
#
# ### Data for each TEAM in the top Italian league after Match Week 7
#
# ### FBref.com — source DataFrame:
#
# # "PASS TYPES"

# %%
import pandas as pd
import numpy as np

# %%
from adjustText import adjust_text

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
#plt.style.use('seaborn-whitegrid')
#plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')

#fig, ax = plt.subplots()

# %%
#plt.style.use(['fivethirtyeight','dark_background'])
#plt.style.use(['seaborn','dark_background'])
#plt.style.use(['ggplot','dark_background'])
#plt.style.use(['seaborn-whitegrid','dark_background'])

plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

sns.set_context(
                'notebook',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %%
import os.path
#~~~~~~~~~~~~~~~~~~~~~~
from PIL import Image
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

image_folder_path = ('~/SBNation_Articles_Soccer_Data/' +
                     'Logo_Pictures_for_Data_Sources/')

logos_flat_path = (image_folder_path +
                   'logos_flat_small.png')

open_flat_logos = os.path.expanduser(logos_flat_path)

logos_flat_small = Image.open(open_flat_logos)

logos_flat_small
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=233x25 at 0x7F867F57B5B0>

# %% [markdown]
# ## PART (1) — LOAD into DataFrame(s)

# %%
Squad_Pass_Types_df = pd.read_csv("Squad_Pass_Types.csv")

Squad_Pass_Types_df
# Out:
#             Squad  # Pl  90s   Att  Live  Dead   FK  TB  Press   Sw  ...  \
# 0        Atalanta    23  7.0  4147  3888   259   90   9    491  127  ...
# 1       Benevento    21  7.0  2921  2564   357  133   6    407   60  ...
# 2         Bologna    22  7.0  3321  2974   347   92   8    433  116  ...
# 3        Cagliari    22  7.0  3151  2809   342   96   5    435   68  ...
# 4         Crotone    25  7.0  3475  3110   365  121   2    520   75  ...
# 5      Fiorentina    23  7.0  3662  3302   360  126   6    396  155  ...
# 6           Genoa    26  7.0  3501  3165   336  105   4    389  111  ...
# 7   Hellas Verona    26  7.0  3086  2748   338  112   1    486   64  ...
# 8           Inter    22  7.0  4489  4172   317   87   8    630  116  ...
# 9        Juventus    23  6.0  3763  3493   270   91   9    504   83  ...
# 10          Lazio    25  7.0  3947  3618   329   87   3    504  113  ...
# 11          Milan    23  7.0  3898  3560   338  118   9    472  103  ...
# ...

# %% [markdown]
# ### Columns list:

# %%
columns_list = list(
                    Squad_Pass_Types_df.columns
                   )
columns_list
# Out:
# ['Squad',
#  '# Pl',
#  '90s',
#  'Att',
#  'Live',
#  'Dead',
#  'FK',
#  'TB',
#  'Press',
#  'Sw',
#  'Crs',
#  'CK',
#  'Inswing',
#  'Outswing',
#  'Straight',
#  'Ground',
#  'Low',
#  'High',
#  'Left',
#  'Right',
#  'Head',
#  'TI',
#  'Other',
#  'Cmp',
#  'Off',
#  'Out',
#  'Int',
#  'Blocks']

# %% [markdown]
# ## PART (2) — identify RANKINGS per column

# %%
Squad_Pass_Types_Ranking_df = Squad_Pass_Types_df.rank(ascending = 0,
                                                 #     '0' = 'False'
                                                       method = 'min')

Squad_Pass_Types_Ranking_df = Squad_Pass_Types_Ranking_df.astype(int)


Squad_Pass_Types_Ranking_df['Squad'] = list(map(str.upper,
                                             Squad_Pass_Types_df['Squad']
                                               )
                                           )
Squad_Pass_Types_Ranking_df
# Out:
#             Squad  # Pl  90s  Att  Live  Dead  FK  TB  Press  Sw  ...  Left  \
# 0        ATALANTA     9    1    3     3    20  18   2      6   2  ...     2
# 1       BENEVENTO    19    1   20    20     4   1   7     14  20  ...    13
# 2         BOLOGNA    14    1   12    12     5  15   5     13   3  ...    15
# 3        CAGLIARI    14    1   15    16     7  14  10     11  18  ...    19
# 4         CROTONE     6    1   11    11     1   3  17      2  17  ...    11
# 5      FIORENTINA     9    1    7     7     3   2   7     15   1  ...    12
# 6           GENOA     2    1    9    10    11   9  14     16   7  ...    18
# 7   HELLAS VERONA     2    1   18    18     9   6  20      8  19  ...     9
# 8           INTER    14    1    1     1    14  19   5      1   3  ...     5
# 9        JUVENTUS     9   19    6     6    19  17   2      4  14  ...     7
# 10          LAZIO     6    1    4     4    13  19  15      4   6  ...     4
# ...

# %%
Squad_Pass_Types_Ranking_df.set_index('Squad',
                                      inplace = True)
Squad_Pass_Types_Ranking_df
# Out:
#                # Pl  90s  Att  Live  Dead  FK  TB  Press  Sw  Crs  ...  Left  \
# Squad                                                              ...
# ATALANTA          9    1    3     3    20  18   2      6   2    7  ...     2
# BENEVENTO        19    1   20    20     4   1   7     14  20   15  ...    13
# BOLOGNA          14    1   12    12     5  15   5     13   3   12  ...    15
# CAGLIARI         14    1   15    16     7  14  10     11  18   13  ...    19
# CROTONE           6    1   11    11     1   3  17      2  17    9  ...    11
# FIORENTINA        9    1    7     7     3   2   7     15   1    5  ...    12
# GENOA             2    1    9    10    11   9  14     16   7   20  ...    18
# HELLAS VERONA     2    1   18    18     9   6  20      8  19    2  ...     9
# INTER            14    1    1     1    14  19   5      1   3    3  ...     5
# JUVENTUS          9   19    6     6    19  17   2      4  14   16  ...     7
# ...

# %%
Squad_Pass_Types_Ranks_Transposed = Squad_Pass_Types_Ranking_df.transpose()

Squad_Pass_Types_Ranks_Transposed
# Out:
# Squad     ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  FIORENTINA  GENOA  \
# # Pl             9         19       14        14        6           9      2
# 90s              1          1        1         1        1           1      1
# Att              3         20       12        15       11           7      9
# Live             3         20       12        16       11           7     10
# Dead            20          4        5         7        1           3     11
# FK              18          1       15        14        3           2      9
# TB               2          7        5        10       17           7     14
# Press            6         14       13        11        2          15     16
# Sw               2         20        3        18       17           1      7
# Crs              7         15       12        13        9           5     20
# CK              18         15        1        11       20          15     19
# ...

# %%
Squad_Pass_Types_Ranks_Transposed.reset_index(inplace = True)

Squad_Pass_Types_Ranks_Transposed.rename(columns = {'index':'SQUAD'
                                                   },
                                       #  order = {
#                                                  'OLD' : 'NEW'
#                                                 }
                                         inplace = True
                                        )
Squad_Pass_Types_Ranks_Transposed
# Out:
# Squad     SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  FIORENTINA  \
# 0          # Pl         9         19       14        14        6           9
# 1           90s         1          1        1         1        1           1
# 2           Att         3         20       12        15       11           7
# 3          Live         3         20       12        16       11           7
# 4          Dead        20          4        5         7        1           3
# 5            FK        18          1       15        14        3           2
# 6            TB         2          7        5        10       17           7
# 7         Press         6         14       13        11        2          15
# 8            Sw         2         20        3        18       17           1
# 9           Crs         7         15       12        13        9           5
# 10           CK        18         15        1        11       20          15
# ...

# %%
Squad_Pass_Types_Rankings = Squad_Pass_Types_Ranks_Transposed.sort_values('INTER')

Squad_Pass_Types_Rankings
# Out:
# Squad     SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  FIORENTINA  \
# 13     Straight         2          6       10        12       17          20
# 1           90s         1          1        1         1        1           1
# 2           Att         3         20       12        15       11           7
# 3          Live         3         20       12        16       11           7
# 22          Cmp         3         20       13        15        9           7
# 15          Low        11         18        9        17        9           8
# 7         Press         6         14       13        11        2          15
# 18        Right         5         19       14        13       12           7
# 14       Ground         3         19       13        14       10           7
# 25          Int         4          8       13        14        1          17
# 10           CK        18         15        1        11       20          15
# ...

# %%
Squad_Pass_Types_Rankings.reset_index(inplace = True,
                                      drop = True)
Squad_Pass_Types_Rankings
# Out:
# Squad     SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  FIORENTINA  \
# 0      Straight         2          6       10        12       17          20
# 1           90s         1          1        1         1        1           1
# 2           Att         3         20       12        15       11           7
# 3          Live         3         20       12        16       11           7
# 4           Cmp         3         20       13        15        9           7
# 5           Low        11         18        9        17        9           8
# 6         Press         6         14       13        11        2          15
# 7         Right         5         19       14        13       12           7
# 8        Ground         3         19       13        14       10           7
# 9           Int         4          8       13        14        1          17
# 10           CK        18         15        1        11       20          15
# ...

# %%
Inter_Rankings_df = (
                     Squad_Pass_Types_Rankings[['SQUAD',
                                                'INTER']]
                     .rename(
                             columns = {
                                        'SQUAD' : 'Pass_Types_Variable'
                                       }
# renamed column input order ~~~~~~~~> {'OLD' : 'NEW'}
                            )
                     .set_index(
                                'Pass_Types_Variable'
                               )
                    )
Inter_Rankings_df
# Out:
# Squad                INTER
# Pass_Types_Variable
# Straight                 1
# 90s                      1
# Att                      1
# Live                     1
# Cmp                      1
# Low                      1
# Press                    1
# Right                    1
# Ground                   2
# Int                      2
# CK                       2
# Sw                       3
# Crs                      3
# TB                       5
# Left                     5
# Head                     6
# TI                       6
# Inswing                  6
# Blocks                   7
# Outswing                 8
# Other                   11
# High                    13
# Dead                    14
# # Pl                    14
# Off                     15
# Out                     17
# FK                      19

# %%
sns.set_context('talk')

Inter_Rankings_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Inter_Ranking_Value_Counts = (
                              Inter_Rankings_df[
                                                'INTER'
                                               ]
                              .value_counts()
                              
                              .reset_index(
                                           name = 'Distinct_Variable_Count'
                                          )
                              .rename(
                                      columns = {
                                                 'index':'PASS_TYPE_Stat_Rank'
                                                }
                                     )
                              .sort_values(
                                           'PASS_TYPE_Stat_Rank'
                                          )
                             )
Inter_Ranking_Value_Counts
# Out:
#     PASS_TYPE_Stat_Rank  Distinct_Variable_Count
# 0                     1                        8
# 2                     2                        3
# 5                     3                        2
# 4                     5                        2
# 1                     6                        3
# 12                    7                        1
# 11                    8                        1
# 10                   11                        1
# 9                    13                        1
# 3                    14                        2
# 8                    15                        1
# 7                    17                        1
# 6                    19                        1

# %% [markdown]
# ## PART (3) — actually PLOTTING the data

# %%
# identify the source time period in SUBTITLE:

subtitle = ' Serie A  (20/21)  data after  Match Week 7'


# duplicate that variable, except spread across 2 lines:

subtitle_2_lines = ('Serie A  (20/21 season)' +
                    '\n' +
                    'data after Match Week 7')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# attribute this work to "InterPool" specifically for S.O.M.:

prod_by_and_for = ('produced by \"InterPool\" for SB Nation\'s  ' +
                   '\n' +
                   'Inter Milan site: Serpents Of Madonnina ')

# %%
sns.set_context(
                'notebook',
                font_scale = 1.8
               )

ax = sns.lmplot(x = 'Press',                       # horizontal axis
                y = 'Cmp',                       # vertical axis
                
                data = Squad_Pass_Types_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 18,              
                aspect = 1.2      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = Squad_Pass_Types_df['Press'].min()
x_col_max = Squad_Pass_Types_df['Press'].max()

y_col_min = Squad_Pass_Types_df['Cmp'].min()
y_col_max = Squad_Pass_Types_df['Cmp'].max()

plt.xlim((x_col_min * 0.98),
         (x_col_max * 1.025)
        )
plt.ylim((y_col_min * 0.95),
         (y_col_max * 1.025)
        )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('Complete Passes - Under PRESSURE vs TOTAL - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('Complete Passes - Under PRESSURE vs TOTAL     ',
             
             x = 0.475,
             y = 1.01,
             
             fontsize = 29,
             
             color = 'yellow'
            )


# identify the source time period in SUBTITLE:

plt.title(
          subtitle_2_lines,
          
          loc = 'left',

          fontsize = 15,
          
          alpha = 0.9,
          
          style = 'italic',

          color = 'goldenrod'
         )


# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,
          
          alpha = 0.7,
          
          style = 'italic',
          
          color = 'lightblue'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Passing COMPLETIONS - under PRESSURE',
           fontsize = 30,
           color = 'yellow'
          )
plt.ylabel('Passing COMPLETIONS - TOTAL',
           fontsize = 30,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1315,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(Squad_Pass_Types_df.Press[i],
                         Squad_Pass_Types_df.Cmp[i],
                         
                         Squad_Pass_Types_df.Squad[i],
                         fontsize = 25
                         
                        ) for i in range(len(Squad_Pass_Types_df.Squad))
               ]


adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 6
