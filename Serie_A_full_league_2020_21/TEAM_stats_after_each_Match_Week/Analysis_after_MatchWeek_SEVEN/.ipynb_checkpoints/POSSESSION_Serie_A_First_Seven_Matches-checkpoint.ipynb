# %% [markdown]
# # Analysis — Serie A (20/21 season)
#
# ### Data for each TEAM in the top Italian league after Match Week 7
#
# ### FBref.com — source DataFrame:
#
# # "POSSESSION"

# %%
import pandas as pd
import numpy as np

# %%
from adjustText import adjust_text

# %%
import os.path
#~~~~~~~~~~~~~~~~~~~~~~
from PIL import Image

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
#plt.style.use('seaborn-whitegrid')
#plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')

#fig, ax = plt.subplots()

# %%
#plt.style.use(['fivethirtyeight','dark_background'])
#plt.style.use(['seaborn','dark_background'])
#plt.style.use(['ggplot','dark_background'])
#plt.style.use(['seaborn-whitegrid','dark_background'])

plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

sns.set_context(
                'paper',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %%
image_folder_path = ('~/SBNation_Articles_Soccer_Data/' +
                     'Logo_Pictures_for_Data_Sources/')

logos_flat_path = (image_folder_path +
                   'logos_flat_small.png')

open_flat_logos = os.path.expanduser(logos_flat_path)

logos_flat_small = Image.open(open_flat_logos)

logos_flat_small
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=233x25 at 0x7FF6AB518FA0>

# %% [markdown]
# ## PART (1) — LOAD into DataFrame(s)

# %%
Possession_df = pd.read_csv("Squad_Possession.csv")

Possession_df
# Out:
#             Squad  # Pl  Poss  90s  Touches  Touches_DefPen  Touches_Def3rd  \
# 0        Atalanta    23  54.9  7.0     4941             362            1345
# 1       Benevento    21  44.1  7.0     3629             489            1359
# 2         Bologna    22  51.4  7.0     4217             507            1322
# 3        Cagliari    22  43.7  7.0     3926             498            1377
# 4         Crotone    25  48.6  7.0     4254             573            1697
# 5      Fiorentina    23  52.0  7.0     4456             468            1358
# 6           Genoa    26  45.7  7.0     4255             557            1729
# 7   Hellas Verona    26  47.0  7.0     3870             466            1224
# 8           Inter    22  60.9  7.0     5183             392            1256
# 9        Juventus    23  57.2  6.0     4376             483            1537
# 10          Lazio    25  51.6  7.0     4703             539            1484
# ...

# %% [markdown]
# ### Columns list:

# %%
columns_list = list(
                    Possession_df.columns
                   )
columns_list
# Out:
# ['Squad',
#  '# Pl',
#  'Poss',
#  '90s',
#  'Touches',
#  'Touches_DefPen',
#  'Touches_Def3rd',
#  'Touches_Mid3rd',
#  'Touches_Att3rd',
#  'Touches_AttPen',
#  'Touches_Live',
#  'Drib_Succ',
#  'Drib_Att',
#  'Drib_Succ_Pct',
#  'Drib_Pl',
#  'Megs',
#  'Carries',
#  'Carries_TotDist',
#  'Carries_PrgDist',
#  'Targ',
#  'Rec',
#  'Rec_Pct',
#  'Miscon',
#  'Dispos']

# %% [markdown]
# ## PART (2) — identify RANKINGS per column

# %%
Possession_Ranking_df = Possession_df.rank(ascending = 0, # 'False'
                                           method = 'min')

Possession_Ranking_df = Possession_Ranking_df.astype(int)


Possession_Ranking_df['Squad'] = list(map(str.upper,
                                          Possession_df['Squad']
                                         ))
Possession_Ranking_df
# Out:
#             Squad  # Pl  Poss  90s  Touches  Touches_DefPen  Touches_Def3rd  \
# 0        ATALANTA     9     5    1        3              19              13
# 1       BENEVENTO    19    17    1       20              10              11
# 2         BOLOGNA    14     9    1       10               8              14
# 3        CAGLIARI    14    18    1       14               9              10
# 4         CROTONE     6    10    1        9               1               2
# 5      FIORENTINA     9     7    1        6              13              12
# 6           GENOA     2    16    1        8               3               1
# 7   HELLAS VERONA     2    13    1       16              14              18
# 8           INTER    14     2    1        1              17              17
# 9        JUVENTUS     9     3   19        7              12               5
# 10          LAZIO     6     8    1        4               5               7
# ...

# %%
Possession_Ranking_df.set_index('Squad',
                                inplace = True)
Possession_Ranking_df
# Out:
#                # Pl  Poss  90s  Touches  Touches_DefPen  Touches_Def3rd  \
# Squad
# ATALANTA          9     5    1        3              19              13
# BENEVENTO        19    17    1       20              10              11
# BOLOGNA          14     9    1       10               8              14
# CAGLIARI         14    18    1       14               9              10
# CROTONE           6    10    1        9               1               2
# FIORENTINA        9     7    1        6              13              12
# GENOA             2    16    1        8               3               1
# HELLAS VERONA     2    13    1       16              14              18
# INTER            14     2    1        1              17              17
# JUVENTUS          9     3   19        7              12               5
# LAZIO             6     8    1        4               5               7
# MILAN             9     4    1        5              15               8
# ...

# %%
Possession_Ranks_Transposed = Possession_Ranking_df.transpose()

Possession_Ranks_Transposed
# Out:
# Squad            ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  FIORENTINA  \
# # Pl                    9         19       14        14        6           9
# Poss                    5         17        9        18       10           7
# 90s                     1          1        1         1        1           1
# Touches                 3         20       10        14        9           6
# Touches_DefPen         19         10        8         9        1          13
# Touches_Def3rd         13         11       14        10        2          12
# Touches_Mid3rd          3         20       10        16       14           6
# Touches_Att3rd          2         18        7        11       14           8
# Touches_AttPen          3         17        6        15       14          11
# Touches_Live            3         20       12        14       10           7
# Drib_Succ               1         20        2         6       18           3
# ...

# %%
Possession_Ranks_Transposed.reset_index(inplace = True)

Possession_Ranks_Transposed.rename(columns = {'index':'SQUAD'
                                             },
                                   # order = {
#                                              'OLD' : 'NEW'
#                                            }
                                   inplace = True
                                  )
Possession_Ranks_Transposed
# Out:
# Squad            SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  \
# 0                 # Pl         9         19       14        14        6
# 1                 Poss         5         17        9        18       10
# 2                  90s         1          1        1         1        1
# 3              Touches         3         20       10        14        9
# 4       Touches_DefPen        19         10        8         9        1
# 5       Touches_Def3rd        13         11       14        10        2
# 6       Touches_Mid3rd         3         20       10        16       14
# 7       Touches_Att3rd         2         18        7        11       14
# 8       Touches_AttPen         3         17        6        15       14
# 9         Touches_Live         3         20       12        14       10
# 10           Drib_Succ         1         20        2         6       18
# 11            Drib_Att         2         20        1         4       17
# ...

# %%
Possession_Rankings = Possession_Ranks_Transposed.sort_values('INTER')
Possession_Rankings
# Out:
# Squad            SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  \
# 2                  90s         1          1        1         1        1
# 3              Touches         3         20       10        14        9
# 20             Rec_Pct        10         15       10        17       12
# 19                 Rec         3         20       13        15        9
# 6       Touches_Mid3rd         3         20       10        16       14
# 7       Touches_Att3rd         2         18        7        11       14
# 8       Touches_AttPen         3         17        6        15       14
# 9         Touches_Live         3         20       12        14       10
# 18                Targ         3         20       13        15        9
# 17     Carries_PrgDist         3         20        9        11       14
# 16     Carries_TotDist         3         20        8        12       13
# 1                 Poss         5         17        9        18       10
# ...

# %%
Possession_Rankings.reset_index(inplace = True,
                                drop = True)
Possession_Rankings
# Out:
# Squad            SQUAD  ATALANTA  BENEVENTO  BOLOGNA  CAGLIARI  CROTONE  \
# 0                  90s         1          1        1         1        1
# 1              Touches         3         20       10        14        9
# 2              Rec_Pct        10         15       10        17       12
# 3                  Rec         3         20       13        15        9
# 4       Touches_Mid3rd         3         20       10        16       14
# 5       Touches_Att3rd         2         18        7        11       14
# 6       Touches_AttPen         3         17        6        15       14
# 7         Touches_Live         3         20       12        14       10
# 8                 Targ         3         20       13        15        9
# 9      Carries_PrgDist         3         20        9        11       14
# 10     Carries_TotDist         3         20        8        12       13
# 11                Poss         5         17        9        18       10
# ...

# %%
Inter_Rankings_df = (
                     Possession_Rankings[['SQUAD',
                                          'INTER']]
                     .rename(
                             columns = {
                                        'SQUAD' : 'Possession_Variable'
                                       }
# renamed column input order ~~~~~~~~> {'OLD' : 'NEW'}
                            )
                     .set_index(
                                'Possession_Variable'
                               )
                    )
Inter_Rankings_df
# Out:
# Squad                INTER
# Possession_Variable
# 90s                      1
# Touches                  1
# Rec_Pct                  1
# Rec                      1
# Touches_Mid3rd           1
# Touches_Att3rd           1
# Touches_AttPen           1
# Touches_Live             1
# Targ                     1
# Carries_PrgDist          1
# Carries_TotDist          1
# Poss                     2
# Miscon                   2
# Carries                  2
# Megs                     3
# Drib_Att                 8
# Dispos                  10
# # Pl                    14
# Drib_Succ               15
# Drib_Pl                 15
# Touches_Def3rd          17
# Touches_DefPen          17
# Drib_Succ_Pct           19

# %%
sns.set_context('talk')

Inter_Rankings_df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Inter_Ranking_Value_Counts = (
                              Inter_Rankings_df[
                                                'INTER'
                                               ]
                              .value_counts()
                              
                              .reset_index(
                                           name = 'Distinct_Variable_Count'
                                          )
                              .rename(
                                      columns = {
                                                 'index':'Possession_Stat_Rank'
                                                }
                                     )
                              .sort_values(
                                           'Possession_Stat_Rank'
                                          )
                             )
Inter_Ranking_Value_Counts
# Out:
#    Possession_Stat_Rank  Distinct_Variable_Count
# 0                     1                       11
# 1                     2                        3
# 8                     3                        1
# 7                     8                        1
# 6                    10                        1
# 5                    14                        1
# 3                    15                        2
# 2                    17                        2
# 4                    19                        1

# %%
TOUCHES_by_PITCH_THIRD_df = (Possession_df[['Squad',
                                            'Touches_Def3rd',
                                            'Touches_Mid3rd',
                                            'Touches_Att3rd'
                                           ]]
                             .sort_values('Touches_Att3rd',
                                          ascending = False
                                         )
                             .set_index('Squad')
                            )
TOUCHES_by_PITCH_THIRD_df
# Out:
#                Touches_Def3rd  Touches_Mid3rd  Touches_Att3rd
# Squad
# Inter                    1256            2661            1651
# Atalanta                 1345            2381            1518
# Milan                    1408            2295            1235
# Napoli                   1057            2186            1226
# Lazio                    1484            2294            1205
# Sassuolo                 1686            2618            1167
# Bologna                  1322            2012            1162
# Fiorentina               1358            2277            1097
# Roma                     1283            2154            1077
# Udinese                  1206            1870            1073
# Juventus                 1537            2144             946
# Cagliari                 1377            1888             946
# Sampdoria                1399            1750             910
# Crotone                  1697            1910             901
# ...

# %% [markdown]
# PRESSING_by_PITCH_THIRD_df = (
#                               Defensive_Actions_df[[
#                                                     'Squad',
#                                                     'Press_Def3rd',
#                                                     'Press_Mid3rd',
#                                                     'Press_Att3rd'
#                                                    ]]
#                               .sort_values(
#                                            'Press_Att3rd',
#                                            ascending = False
#                                           )
#                               .set_index(
#                                          'Squad'
#                                         )
#                              )
# PRESSING_by_PITCH_THIRD_df

# %% [markdown]
# ## PART (3) — actually PLOTTING the data

# %% [markdown]
# #### define STRINGS for subtitle and for naming myself + S.O.M.

# %%
# identify the source time period in SUBTITLE:

#subtitle = ' data:  Serie A  (20/21)  after  Match Week 7'

subtitle = ' Serie A  (20/21)  data after  Match Week 7'


# duplicate that variable, except spread across 2 lines:

subtitle_2_lines = (#'data: Serie A (20/21)' +
                    'Serie A  (20/21 season)' +
                    '\n' +
                    'data after Match Week 7')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# attribute this work to "InterPool" specifically for S.O.M.:

prod_by_and_for = ('produced by \"InterPool\" for SB Nation\'s  ' +
                   '\n' +
                   'Inter Milan site: Serpents Of Madonnina ')



# duplicate that variable, except printed in only a single line:
#prod_by_and_for_1_line = ('produced by \"InterPool\" for SB Nation\'s  ' +
#                          'Inter Milan site: Serpents Of Madonnina ')

# %% [markdown]
# ## GROUPED BAR CHART:

# %%
def label_bar_y_vals(bar_group, x_offset):
    
    for each_bar in bar_group:
        
        bar_height = each_bar.get_height()
        
        ax.annotate('{}'.format(bar_height),
                    
                    xy = (each_bar.get_x() +
                          each_bar.get_width() / 2,
                          bar_height
                         ),
                    
                    xytext = (x_offset, # horizontal offset variable input
                              2   # 2 pts vertical offset
                             ),
                    
                    textcoords = 'offset points',
                    
                    ha = 'center',  # horizontal alignment
                    va = 'bottom'   # vertical alignment
                   )

# %%
sns.set_context(
                'poster',
                font_scale = 0.67
               )

fig, ax = plt.subplots(
                       figsize = (
                                  30,  # horizontal WIDTH
                                  12    # vertical HEIGHT
                                 )
                      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#### set the positions and width for the bars

#pos = list(range(
#                 len(
#                     TOUCHES_by_PITCH_THIRD_df['Touches_Def3rd']
#                    )
#                ))

pos_list = list(
                range(
                      len(
                          TOUCHES_by_PITCH_THIRD_df['Touches_Def3rd']
                         )
                     )
               )

pos = [each_pos * 3.5 for each_pos in pos_list]


width = 0.85

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#### create the bars, in position pos, for Y-axis Variable #1
bar_group_1 = plt.bar(pos,
                      
                      TOUCHES_by_PITCH_THIRD_df['Touches_Def3rd'],
                      
                      width,  #alpha = 0.9,
                      color = 'purple'
                     )

#### create bars, in position pos + width buffer, for Y-axis Variable #2
bar_group_2 = plt.bar([(p + width
                       ) for p in pos
                      ],
                      
                      TOUCHES_by_PITCH_THIRD_df['Touches_Mid3rd'],
                      
                      width,  #alpha = 0.9,
                      color = 'green'
                     )

#### create bars, in position pos + width buffer, for Y-axis Variable #3
bar_group_3 = plt.bar([(p + width*2
                       ) for p in pos
                      ],
                      
                      TOUCHES_by_PITCH_THIRD_df['Touches_Att3rd'],
                      
                      width,
                      alpha = 0.8,
                      color = 'orange'
                     )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#ax.set_title('Test', fontsize = 60)

#plt.title('TOUCHES - Team Totals per Third of the Pitch - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'lightblue')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.title(('TOUCHES - Team Totals per Third of the Pitch' +
           '    '
          ),
          
#          loc = 'left',
          
          fontsize = 25,     # 30,
          color = 'yellow'   # 'goldenrod'
         )

# identify the source time period in SUBTITLE:

plt.title(subtitle,
          #('                          - ' + subtitle),
          #subtitle_2_lines,

          loc = 'left',
          
          fontsize = 22,
          
          alpha = 0.9,
          
          style = 'italic',
          
          color = 'goldenrod'    # 'darkgoldenrod'
         )

# attribute this work to "InterPool" specifically for S.O.M.

#plt.title(#prod_by_and_for,
#          #prod_by_and_for_1_line,
#          ('                                      ' +
#           prod_by_and_for_1_line),

##          loc = 'right',
#          fontsize = 17.5,
#          color = 'lightblue')

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.text(48.5,     # 45,  # 15,
         2790,     # 2800,   # 2500,
         
         prod_by_and_for,
         
         fontsize = 11,      # 10,
         
         alpha = 0.7,
         
         style = 'italic',
         
         color = 'lightblue'
        )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# NOTE -- X and Y values for "figimage" origin are defined in PIXELS

plt.figimage(logos_flat_small,
             1492,  # 1307,
             708
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set_xticks(
              [
               (p + width
               ) for p in pos
              ]
             )

ax.set_xticklabels(TOUCHES_by_PITCH_THIRD_df.index,
                   
                   fontsize = 15,
                   
                   rotation = 345
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlim(
         min(pos) - (width * 1.75),
         max(pos) + (width * 3.35)
        )

plt.ylim([
          0,
          (max(
               TOUCHES_by_PITCH_THIRD_df['Touches_Mid3rd']
              ) * 1.04)
         ])

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.legend(
           [
            'DEFENSIVE third',
            'MIDDLE third',
            'ATTACKING third'
           ],
           loc = 'upper right'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# use the custom function defined above to...
# ...label the y-values for each bar in each bar group

label_bar_y_vals(bar_group_1,
                 -10  # x_offset variable
                )

label_bar_y_vals(bar_group_2,
                 0  # x_offset variable
                )

label_bar_y_vals(bar_group_3,
                 10  # x_offset variable
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.grid()

plt.show()

# %% [markdown]
# ### identify the source variables in MAIN TITLE:
#
# plt.title(('TOUCHES - Team Totals per Third of the Pitch' +
#            '    '
#           ),
#
#           fontsize = 25,
#           color = 'yellow'
#          )
#
#
# ### identify the source time period in SUBTITLE:
#
# plt.title(subtitle,
#
#           loc = 'left',
#
#           fontsize = 22,
#
#           alpha = 0.9,
#
#           style = 'italic',
#
#           color = 'goldenrod'
#          )
#
#
# ### attribute this work to "InterPool" specifically for S.O.M.
#
# plt.text(48.5,
#
#          2790,
#
#          prod_by_and_for,
#
#          fontsize = 11,
#
#          alpha = 0.7,
#
#          style = 'italic',
#
#          color = 'lightblue'
#         )

# %% [markdown]
# ## SCATTERPLOTS:

# %%
sns.set_context(
                'notebook',
                font_scale = 1.6
               )

ax = sns.lmplot(x = 'Touches',                       # horizontal axis
                y = 'Touches_Live',                   # vertical axis
                
                data = Possession_df,     # data source
                
                fit_reg = False,            # do NOT fix a regression line
                #fit_reg = True,
                
                height = 15,              
                aspect = 1.2      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = Possession_df['Touches'].min()
x_col_max = Possession_df['Touches'].max()

y_col_min = Possession_df['Touches_Live'].min()
y_col_max = Possession_df['Touches_Live'].max()

plt.xlim(
         (x_col_min * 0.98),
         (x_col_max * 1.005)
        )
plt.ylim(
         (y_col_min * 0.97),
         (y_col_max * 1.03)
        )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('TOUCHES - Total vs Live Ball - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('TOUCHES - Total vs Live Ball',
             
             x = 0.475,
             y = 1.01,
             
             fontsize = 28,
             
             color = 'yellow'
            )

# identify the source time period in SUBTITLE:

plt.title(#subtitle
          subtitle_2_lines,
          
          loc = 'left',

          fontsize = 15,
          
          alpha = 0.9,
          
          style = 'italic',

          color = 'goldenrod'
         )

# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,
          
          alpha = 0.7,
          
          style = 'italic',
          
          color = 'lightblue'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Touches - TOTAL',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('Touches - LIVE BALL',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1075,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(
                         Possession_df.Touches[i],
                         Possession_df.Touches_Live[i],
                         
                         Possession_df.Squad[i],
                         fontsize = 20
                         
                        ) for i in range(len(Possession_df.Squad))
               ]

adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 368

# %%
sns.set_context(
                'notebook',
                font_scale = 1.6
               )

ax = sns.lmplot(x = 'Touches_Att3rd',                       # horizontal axis
                y = 'Touches_Def3rd',                   # vertical axis
                
                data = Possession_df,     # data source
                
                #fit_reg = False,            # do NOT fix a regression line
                fit_reg = True,
                
                height = 15,              
                aspect = 1.4      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = Possession_df['Touches_Att3rd'].min()
x_col_max = Possession_df['Touches_Att3rd'].max()

y_col_min = Possession_df['Touches_Def3rd'].min()
y_col_max = Possession_df['Touches_Def3rd'].max()

plt.xlim(
         (x_col_min * 0.98),
         (x_col_max * 1.01)
        )
plt.ylim(
         (y_col_min * 0.97),
         (y_col_max * 1.015)
        )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

#plt.title('TOUCHES - Attacking vs Defensive Third - Serie A (20/21) after matchweek 7',
#          fontsize = 25,
#          color = 'goldenrod')


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('TOUCHES - Attacking vs Defensive Third',
             
             x = 0.475,      #0.204,   # 0.25,
             y = 1.01,      # .03,   # 1.04,
             
             fontsize = 28,    # 30,
             
             color = 'yellow'    # 'goldenrod'
            )

# identify the source time period in SUBTITLE:

plt.title(#subtitle
          subtitle_2_lines,
          
          loc = 'left',   # 'right',

          fontsize = 15,   # 20,
          
          alpha = 0.9,    # 0.7,   # 0.6,
          
          style = 'italic',

          color = 'goldenrod'
         )

# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,  # 20,
          
          alpha = 0.7,    # 0.6,   # 0.8,
          
          style = 'italic',
          
          color = 'lightblue'  # 'goldenrod'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Touches - ATTACKING third of the pitch',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('Touches - DEFENSIVE third of the pitch',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1275,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(
                         Possession_df.Touches_Att3rd[i],
                         Possession_df.Touches_Def3rd[i],
                         
                         Possession_df.Squad[i],
                         fontsize = 20
                         
                        ) for i in range(len(Possession_df.Squad))
               ]

adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 6

# %%
sns.set_context(
                'notebook',
                font_scale = 1.6
               )

ax = sns.lmplot(x = 'Carries_PrgDist',                       # horizontal axis
                y = 'Carries_TotDist',                   # vertical axis
                
                data = Possession_df,     # data source
                
                fit_reg = False,            # do NOT fix a regression line
                #fit_reg = True,
                
                height = 15,              
                aspect = 1.2      #  dimension of x-axis (sets width)
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

x_col_min = Possession_df['Carries_PrgDist'].min()
x_col_max = Possession_df['Carries_PrgDist'].max()

y_col_min = Possession_df['Carries_TotDist'].min()
y_col_max = Possession_df['Carries_TotDist'].max()

plt.xlim(
         (x_col_min * 0.98),
         (x_col_max * 1.005)
        )
plt.ylim(
         (y_col_min * 0.97),
         (y_col_max * 1.02)
        )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# identify the source variables in MAIN TITLE:

plt.suptitle('CARRIES - Total vs Progressive Distance',
             
             x = 0.475,      #0.204,   # 0.25,
             y = 1.01,      # .03,   # 1.04,
             
             fontsize = 28,    # 30,
             
             color = 'yellow'    # 'goldenrod'
            )

# identify the source time period in SUBTITLE:

plt.title(#subtitle
          subtitle_2_lines,
          
          loc = 'left',   # 'right',

          fontsize = 15,   # 20,
          
          alpha = 0.9,    # 0.7,   # 0.6,
          
          style = 'italic',

          color = 'goldenrod'
         )

# attribute this work to "InterPool" specifically for S.O.M.

plt.title(prod_by_and_for,
          
          loc = 'right',
          
          fontsize = 15,  # 20,
          
          alpha = 0.7,    # 0.6,   # 0.8,
          
          style = 'italic',
          
          color = 'lightblue'  # 'goldenrod'
         )

#plt.suptitle(prod_by_and_for,
#             x = 0.8, y = 1.04,
#             fontsize = 15, color = 'goldenrod')

#  ^ doesn't work correctly - there can only be one "suptitle"

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.xlabel('Carries - TOTAL Distance',
           fontsize = 25,
           color = 'yellow'
          )
plt.ylabel('Carries - PROGRESSIVE Distance',
           fontsize = 25,
           color = 'yellow'
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.figimage(
             logos_flat_small,
             
             1060,
             5
            )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

point_labels = [plt.text(
                         Possession_df.Carries_PrgDist[i],
                         Possession_df.Carries_TotDist[i],
                         
                         Possession_df.Squad[i],
                         fontsize = 20
                         
                        ) for i in range(len(Possession_df.Squad))
               ]

adjust_text(point_labels,
            arrowprops = dict(arrowstyle = '->',
                              color = 'red')
           )
# Out:
# 6

# %% [markdown]
# ### identify the source variables in MAIN TITLE:
#
# plt.suptitle('CARRIES - Total vs Progressive Distance',
#
#              x = 0.475,
#              y = 1.01,
#
#              fontsize = 28,
#
#              color = 'yellow'
#             )
#
#
# ### identify the source time period in SUBTITLE:
#
# plt.title(
#           subtitle_2_lines,
#
#           loc = 'left',
#
#           fontsize = 15,
#
#           alpha = 0.9,
#
#           style = 'italic',
#
#           color = 'goldenrod'
#          )
#
#
# ### attribute this work to "InterPool" specifically for S.O.M.
#
# plt.title(prod_by_and_for,
#
#           loc = 'right',
#
#           fontsize = 15,
#
#           alpha = 0.7,
#
#           style = 'italic',
#
#           color = 'lightblue'
#          )
