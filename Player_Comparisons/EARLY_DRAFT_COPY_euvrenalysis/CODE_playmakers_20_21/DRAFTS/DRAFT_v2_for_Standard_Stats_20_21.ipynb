# %%
import pandas as pd
#~~~~~~~~~~~~~~~~~~~~
import numpy as np

# %%
import os.path
#~~~~~~~~~~~~~~~~~~~~~~
from PIL import Image

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %matplotlib inline

# %%
plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

sns.set_context(
                'paper',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %% [markdown]
# # PART (1) — LOAD from CSV to DataFrame

# %%
data_folder_path = ('~/SBNation_Articles_Soccer_Data/' +
                     'Player_Comparisons/' +
                     'Oeuvrenalysis_Calhanoglu/' +
                     'DATA_playmakers_20_21/')
data_folder_path
# Out:
# '~/SBNation_Articles_Soccer_Data/Player_Comparisons/Oeuvrenalysis_Calhanoglu/DATA_playmakers_20_21/'

# %%
file_path = (data_folder_path +
             'Standard_Stats_20_21.csv')
file_path
# Out:
# '~/SBNation_Articles_Soccer_Data/Player_Comparisons/Oeuvrenalysis_Calhanoglu/DATA_playmakers_20_21/Standard_Stats_20_21.csv'

# %%
Standard_Stats_df = pd.read_csv(file_path)

# %%
Standard_Stats_df
# Out:
#               Player     Span Nation   Pos  Squad  MP  Starts   Min   90s  \
# 0  Christian Eriksen  2020-21    DEN    MF  Inter  26      17  1385  15.4
# 1       Luis Alberto  2020-21    ESP    MF  Lazio  34      33  2618  29.1
# 2   Hakan Çalhanoğlu  2020-21    TUR  MFFW  Milan  33      30  2614  29.0
#
#    Gls  ...  G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  \
# 0    3  ...           0.19  1.7   1.7  2.6      4.3       0.11       0.17
# 1    9  ...           0.38  5.5   5.3  8.2     13.5       0.19       0.28
# 2    4  ...           0.41  5.5   4.8  8.8     13.5       0.19       0.30
#
#    xG+xA_per_90  npxG_per_90  npxG+xA_per_90
# 0          0.28         0.11            0.28
# 1          0.47         0.18            0.46
# 2          0.49         0.16            0.47
#
# [3 rows x 30 columns]

# %%
columns_list = list(
                    Standard_Stats_df.columns
                   )
columns_list
# Out:
# ['Player',
#  'Span',
#  'Nation',
#  'Pos',
#  'Squad',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Gls',
#  'Ast',
#  'G-PK',
#  'PK',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Gls_per_90',
#  'Ast_per_90',
#  'G+A_per_90',
#  'G-PK_per_90',
#  'G+A-PK_per_90',
#  'xG',
#  'npxG',
#  'xA',
#  'npxG+xA',
#  'xG_per_90',
#  'xA_per_90',
#  'xG+xA_per_90',
#  'npxG_per_90',
#  'npxG+xA_per_90']

# %%
Stat_Numbers = Standard_Stats_df.loc[:,
                                     'MP':'npxG+xA_per_90'
                                    ]
Stat_Numbers
# Out:
#    MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  CrdY  ...  \
# 0  26      17  1385  15.4    3    0     3   0      0     1  ...
# 1  34      33  2618  29.1    9    2     9   0      0     5  ...
# 2  33      30  2614  29.0    4    9     3   1      1     4  ...
#
#    G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  xG+xA_per_90  \
# 0           0.19  1.7   1.7  2.6      4.3       0.11       0.17          0.28
# 1           0.38  5.5   5.3  8.2     13.5       0.19       0.28          0.47
# 2           0.41  5.5   4.8  8.8     13.5       0.19       0.30          0.49
#
#    npxG_per_90  npxG+xA_per_90
# 0         0.11            0.28
# 1         0.18            0.46
# 2         0.16            0.47
#
# [3 rows x 25 columns]

# %%
#Stats_df = 

Stat_Numbers.insert(loc = 0,
                               column = 'Player',
                               value = Standard_Stats_df['Player']
                              )

# %%
Stat_Numbers
# Out:
#               Player  MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  ...  \
# 0  Christian Eriksen  26      17  1385  15.4    3    0     3   0      0  ...
# 1       Luis Alberto  34      33  2618  29.1    9    2     9   0      0  ...
# 2   Hakan Çalhanoğlu  33      30  2614  29.0    4    9     3   1      1  ...
#
#    G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  xG+xA_per_90  \
# 0           0.19  1.7   1.7  2.6      4.3       0.11       0.17          0.28
# 1           0.38  5.5   5.3  8.2     13.5       0.19       0.28          0.47
# 2           0.41  5.5   4.8  8.8     13.5       0.19       0.30          0.49
#
#    npxG_per_90  npxG+xA_per_90
# 0         0.11            0.28
# 1         0.18            0.46
# 2         0.16            0.47
#
# [3 rows x 26 columns]

# %%
Stats_df = Stat_Numbers

Stats_df
# Out:
#               Player  MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  ...  \
# 0  Christian Eriksen  26      17  1385  15.4    3    0     3   0      0  ...
# 1       Luis Alberto  34      33  2618  29.1    9    2     9   0      0  ...
# 2   Hakan Çalhanoğlu  33      30  2614  29.0    4    9     3   1      1  ...
#
#    G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  xG+xA_per_90  \
# 0           0.19  1.7   1.7  2.6      4.3       0.11       0.17          0.28
# 1           0.38  5.5   5.3  8.2     13.5       0.19       0.28          0.47
# 2           0.41  5.5   4.8  8.8     13.5       0.19       0.30          0.49
#
#    npxG_per_90  npxG+xA_per_90
# 0         0.11            0.28
# 1         0.18            0.46
# 2         0.16            0.47
#
# [3 rows x 26 columns]

# %%
Stats_df.set_index('Player',
                   inplace = True
                  )

Stats_df
# Out:
#                    MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  CrdY  \
# Player
# Christian Eriksen  26      17  1385  15.4    3    0     3   0      0     1
# Luis Alberto       34      33  2618  29.1    9    2     9   0      0     5
# Hakan Çalhanoğlu   33      30  2614  29.0    4    9     3   1      1     4
#
#                    ...  G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  \
# Player             ...
# Christian Eriksen  ...           0.19  1.7   1.7  2.6      4.3       0.11
# Luis Alberto       ...           0.38  5.5   5.3  8.2     13.5       0.19
# Hakan Çalhanoğlu   ...           0.41  5.5   4.8  8.8     13.5       0.19
#
#                    xA_per_90  xG+xA_per_90  npxG_per_90  npxG+xA_per_90
# Player
# Christian Eriksen       0.17          0.28         0.11            0.28
# Luis Alberto            0.28          0.47         0.18            0.46
# Hakan Çalhanoğlu        0.30          0.49         0.16            0.47
#
# [3 rows x 25 columns]

# %% [markdown]
# # PART (2) — identify RANKINGS per column

# %%
Stat_RANKS_df = (Stats_df.rank(ascending = 0,
                              #     '0' = 'False'
                               method = 'min'
                              )
                    .astype(int)
                   )

# %%
Stat_RANKS_df
# Out:
#                    MP  Starts  Min  90s  Gls  Ast  G-PK  PK  PKatt  CrdY  ...  \
# Player                                                                    ...
# Christian Eriksen   3       3    3    3    3    3     2   2      2     3  ...
# Luis Alberto        1       1    1    1    1    2     1   2      2     1  ...
# Hakan Çalhanoğlu    2       2    2    2    2    1     2   1      1     2  ...
#
#                    G+A-PK_per_90  xG  npxG  xA  npxG+xA  xG_per_90  xA_per_90  \
# Player
# Christian Eriksen              3   3     3   3        3          3          3
# Luis Alberto                   2   1     1   2        1          1          2
# Hakan Çalhanoğlu               1   1     2   1        1          1          1
#
#                    xG+xA_per_90  npxG_per_90  npxG+xA_per_90
# Player
# Christian Eriksen             3            3               3
# Luis Alberto                  2            1               2
# Hakan Çalhanoğlu              1            2               1
#
# [3 rows x 25 columns]

# %%
#Stat_RANKS_df.plot.hist()

# %% [markdown]
# # PART (3) — TRANSPOSE both OG and RANKS dataframes

# %%
Stats_Transposed = Stats_df.transpose()

Stats_Transposed
# Out:
# Player          Christian Eriksen  Luis Alberto  Hakan Çalhanoğlu
# MP                          26.00         34.00             33.00
# Starts                      17.00         33.00             30.00
# Min                       1385.00       2618.00           2614.00
# 90s                         15.40         29.10             29.00
# Gls                          3.00          9.00              4.00
# Ast                          0.00          2.00              9.00
# G-PK                         3.00          9.00              3.00
# PK                           0.00          0.00              1.00
# PKatt                        0.00          0.00              1.00
# CrdY                         1.00          5.00              4.00
# CrdR                         0.00          0.00              0.00
# Gls_per_90                   0.19          0.31              0.14
# Ast_per_90                   0.00          0.07              0.31
# G+A_per_90                   0.19          0.38              0.45
# G-PK_per_90                  0.19          0.31              0.10
# G+A-PK_per_90                0.19          0.38              0.41
# xG                           1.70          5.50              5.50
# npxG                         1.70          5.30              4.80
# xA                           2.60          8.20              8.80
# npxG+xA                      4.30         13.50             13.50
# xG_per_90                    0.11          0.19              0.19
# xA_per_90                    0.17          0.28              0.30
# xG+xA_per_90                 0.28          0.47              0.49
# npxG_per_90                  0.11          0.18              0.16
# npxG+xA_per_90               0.28          0.46              0.47

# %%
Ranks_Transposed = Stat_RANKS_df.transpose()

Ranks_Transposed
# Out:
# Player          Christian Eriksen  Luis Alberto  Hakan Çalhanoğlu
# MP                              3             1                 2
# Starts                          3             1                 2
# Min                             3             1                 2
# 90s                             3             1                 2
# Gls                             3             1                 2
# Ast                             3             2                 1
# G-PK                            2             1                 2
# PK                              2             2                 1
# PKatt                           2             2                 1
# CrdY                            3             1                 2
# CrdR                            1             1                 1
# Gls_per_90                      2             1                 3
# Ast_per_90                      3             2                 1
# G+A_per_90                      3             2                 1
# G-PK_per_90                     2             1                 3
# G+A-PK_per_90                   3             2                 1
# xG                              3             1                 1
# npxG                            3             1                 2
# xA                              3             2                 1
# npxG+xA                         3             1                 1
# xG_per_90                       3             1                 1
# xA_per_90                       3             2                 1
# xG+xA_per_90                    3             2                 1
# npxG_per_90                     3             1                 2
# npxG+xA_per_90                  3             2                 1

# %%
Ranks_Transposed.plot.hist(#bins = 3

                           #by = "Christian Eriksen",
                           # "Christian Eriksen",

                           use_index = True,

                           #legend = {'reverse'},

                           #,

                           subplots = True,

                           sharex = True,

                           sharey = True,

                           #fontsize = 1.2,

                           xticks = (1,
                                     2,
                                     3
                                    ),  # ,

                           # figsize = 2,
                           figsize = (
                                      15,  # width (inches)
                                      5  # height (also inches)
                                     ),

                           layout = (1,  # number of "rows" for subplots
                                     3  # number of subplot "columns"
                                    )

                           #,

                           #,

                          )
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %%
Ranks_Transposed.plot.hist(use_index = True,

                           subplots = True,

                           sharex = True,
                           sharey = True,

                           xticks = (1, 2, 3
                                    ),
                           
                           # alpha = 0.5,
                           
                           title = "Histogram of Frequency per Ranking for each player",

                           figsize = (14,  # width (inches)
                                      6  # height (also inches)
                                     ),

                           layout = (1,  # number of "rows" for subplots
                                     3  # number of subplot "columns"
                                    )
                          )
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %%
Ranks_Transposed.plot.hist(use_index = True,

                           subplots = True,
                           
                           orientation = 'horizontal',

                           yticks = (1, 2, 3
                                    ),
                           
#                            yticks = (3,
#                                      2,
#                                      1
#                                     ),
                           
                           sharex = True,
                           sharey = True,

#                            xticks = (1, 2, 3
#                                     ),
                           
                           color = ('gold',   #  Eriksen
                                    #'yellow',
                                    
                                    'aqua',  # Luis Alberto
                                    #'lightblue',
                                    
                                    'crimson'   #  Calhanoglu
                                    #'red',
                                   ),
                           
                           # alpha = 0.8,
                           
                           # rwidth = 5,     # 3.5,    # 1.5,   # 0.9,
                           
                           title = "Histogram of Each Player's Count per Ranking for All Variables",

#                            figsize = (15,  # width (inches)
#                                       10  # height (also inches)
#                                      ),
                           
                           figsize = (10,  # width (inches)
                                      8  # height (also inches)
                                     ),

                           layout = (3,  # number of "rows" for subplots
                                     1  # number of subplot "columns"
                                    )
                          )
# Out:
# array([[<AxesSubplot:xlabel='Frequency'>],
#        [<AxesSubplot:xlabel='Frequency'>],
#        [<AxesSubplot:xlabel='Frequency'>]], dtype=object)

# %%
Ranks_Transposed.plot.hist(use_index = True,

                           subplots = True,
                           
                           orientation = 'horizontal',
                           
                           
                           figsize = (11,  # width (inches)
                                      8  # height (also inches)
                                     ),

                           layout = (3,  # number of "rows" for subplots
                                     1  # number of subplot "columns"
                                    ),

                           yticks = (# 0,
                                     1, 2, 3   #  ,
                                     # 4
                                    ),
                           
                           sharex = True,
                           sharey = True,

                           
                           color = ('gold',  #  Eriksen
                                    'aqua',   #  Luis Alberto
                                    'crimson'  #  Calhanoglu
                                   ),
                           
                           title = "Histogram: Each Player's Count per Ranking (All Variables)"
                          )
# Out:
# array([[<AxesSubplot:xlabel='Frequency'>],
#        [<AxesSubplot:xlabel='Frequency'>],
#        [<AxesSubplot:xlabel='Frequency'>]], dtype=object)

# %% [markdown]
# # PART (4) -- JOIN (not "merge" or "concat") STATS df + RANKS df

# %%
stats_and_ranks = Stats_Transposed.join(Ranks_Transposed,
                                        
                                        lsuffix = ' STATS',
                                        
                                        rsuffix = ' RANK'
                                       )
stats_and_ranks
# Out:
# Player          Christian Eriksen STATS  Luis Alberto STATS  \
# MP                                26.00               34.00
# Starts                            17.00               33.00
# Min                             1385.00             2618.00
# 90s                               15.40               29.10
# Gls                                3.00                9.00
# Ast                                0.00                2.00
# G-PK                               3.00                9.00
# PK                                 0.00                0.00
# PKatt                              0.00                0.00
# CrdY                               1.00                5.00
# CrdR                               0.00                0.00
# Gls_per_90                         0.19                0.31
# Ast_per_90                         0.00                0.07
# G+A_per_90                         0.19                0.38
# G-PK_per_90                        0.19                0.31
# G+A-PK_per_90                      0.19                0.38
# xG                                 1.70                5.50
# npxG                               1.70                5.30
# xA                                 2.60                8.20
# npxG+xA                            4.30               13.50
# xG_per_90                          0.11                0.19
# xA_per_90                          0.17                0.28
# xG+xA_per_90                       0.28                0.47
# npxG_per_90                        0.11                0.18
# npxG+xA_per_90                     0.28                0.46
#
# Player          Hakan Çalhanoğlu STATS  Christian Eriksen RANK  \
# MP                               33.00                       3
# Starts                           30.00                       3
# Min                            2614.00                       3
# 90s                              29.00                       3
# Gls                               4.00                       3
# Ast                               9.00                       3
# G-PK                              3.00                       2
# PK                                1.00                       2
# PKatt                             1.00                       2
# CrdY                              4.00                       3
# CrdR                              0.00                       1
# Gls_per_90                        0.14                       2
# Ast_per_90                        0.31                       3
# G+A_per_90                        0.45                       3
# G-PK_per_90                       0.10                       2
# G+A-PK_per_90                     0.41                       3
# xG                                5.50                       3
# npxG                              4.80                       3
# xA                                8.80                       3
# npxG+xA                          13.50                       3
# xG_per_90                         0.19                       3
# xA_per_90                         0.30                       3
# xG+xA_per_90                      0.49                       3
# npxG_per_90                       0.16                       3
# npxG+xA_per_90                    0.47                       3
#
# Player          Luis Alberto RANK  Hakan Çalhanoğlu RANK
# MP                              1                      2
# Starts                          1                      2
# Min                             1                      2
# 90s                             1                      2
# Gls                             1                      2
# Ast                             2                      1
# G-PK                            1                      2
# PK                              2                      1
# PKatt                           2                      1
# CrdY                            1                      2
# CrdR                            1                      1
# Gls_per_90                      1                      3
# Ast_per_90                      2                      1
# G+A_per_90                      2                      1
# G-PK_per_90                     1                      3
# G+A-PK_per_90                   2                      1
# xG                              1                      1
# npxG                            1                      2
# xA                              2                      1
# npxG+xA                         1                      1
# xG_per_90                       1                      1
# xA_per_90                       2                      1
# xG+xA_per_90                    2                      1
# npxG_per_90                     1                      2
# npxG+xA_per_90                  2                      1

# %% [markdown]
# # ("/SBNation_Articles_Soccer_Data" +
#
# #  "/Serie_A_full_league_2020_21" +
#
# #  "/KM_RUN_all_Serie_A_20_21.csv")
