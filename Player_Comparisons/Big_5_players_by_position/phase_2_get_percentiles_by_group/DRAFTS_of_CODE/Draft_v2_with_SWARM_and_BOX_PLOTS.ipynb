# %% [markdown]
# # "Oeuvre-nalysis" Project - Phase 2

# %%
import pandas as pd
#~~~~~~~~~~~~~~~~~~~~
import numpy as np
#~~~~~~~~~~~~~~~~~~~~
import os.path

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
from adjustText import adjust_text

# %%
# %matplotlib inline

# %%
plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
sns.set_context(
                'paper',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %% [markdown]
# .
#
# # LOAD the "cleaned" data output from this project's "Step 1"

# %% [markdown]
# #### 1. STANDARD_stats.csv
#
#
# #### 2. SHOOTING_stats.csv
#
#
# #### 3. GCA_and_SCA.csv
#
#
# #### 4. PASSING.csv
#
#
# #### 5. PASS_TYPES.csv
#
#
# #### 6. POSSESSION.csv
#
#
# #### 7. DEFENSIVE_ACTIONS.csv

# %% [markdown]
# .
#
# # CSV (1): "STANDARD_stats"

# %%
data_folder_path = ('~/SBNation_Articles_Soccer_Data/' +
                    'Player_Comparisons/' +
                    
                    'Big_5_players_by_position/' +
                    
#                     'DATA_clean_grouped_by_position_20_21/'
                    
                    'CLEAN_but_ungrouped_DATA/'
                   )
data_folder_path
# Out:
# '~/SBNation_Articles_Soccer_Data/Player_Comparisons/Big_5_players_by_position/CLEAN_but_ungrouped_DATA/'

# %%
file_path = (data_folder_path +
             'STANDARD_stats.csv'
            )
file_path
# Out:
# '~/SBNation_Articles_Soccer_Data/Player_Comparisons/Big_5_players_by_position/CLEAN_but_ungrouped_DATA/STANDARD_stats.csv'

# %%
STANDARD_stats = pd.read_csv(file_path)

# %%
STANDARD_stats
# Out:
#                    Player Nation   Pos           Squad            Comp   Age  \
# 0           Ismael Aaneba    FRA  FWDF      Strasbourg         Ligue 1  21.0
# 1     Patrick van Aanholt    NED    DF  Crystal Palace  Premier League  29.0
# 2             Issah Abbas    GHA  DFFW        Mainz 05      Bundesliga  21.0
# 3        Yunis Abdelhamid    MAR    DF           Reims         Ligue 1  32.0
# 4           Sabit Abdulai    GHA    MF          Getafe         La Liga  21.0
# ...                   ...    ...   ...             ...             ...   ...
# 2818         Steven Zuber    SUI  DFMF  Eint Frankfurt      Bundesliga  28.0
# 2819     Martín Zubimendi    ESP    MF   Real Sociedad         La Liga  21.0
# 2820      Martin Ødegaard    NOR    MF         Arsenal  Premier League  21.0
# 2821      Martin Ødegaard    NOR  MFFW     Real Madrid         La Liga  21.0
# 2822        Filip Đuričić    SRB  MFFW        Sassuolo         Serie A  28.0
#
# ...

# %% [markdown]
# # FILTER out all players with LESS than 500 minutes played

# %%
STANDARD_stats_df = STANDARD_stats[
                                   STANDARD_stats['Min'
                                                 ] >= 500
                                  ]

# %%
STANDARD_stats_df
# Out:
#                    Player Nation   Pos           Squad            Comp   Age  \
# 1     Patrick van Aanholt    NED    DF  Crystal Palace  Premier League  29.0
# 3        Yunis Abdelhamid    MAR    DF           Reims         Ligue 1  32.0
# 5             Mehdi Abeid    ALG    MF          Nantes         Ligue 1  27.0
# 6         Laurent Abergel    FRA    MF         Lorient         Ligue 1  27.0
# 7             Charles Abi    FRA  FWMF   Saint-Étienne         Ligue 1  20.0
# ...                   ...    ...   ...             ...             ...   ...
# 2817        Igor Zubeldia    ESP    DF   Real Sociedad         La Liga  23.0
# 2818         Steven Zuber    SUI  DFMF  Eint Frankfurt      Bundesliga  28.0
# 2819     Martín Zubimendi    ESP    MF   Real Sociedad         La Liga  21.0
# 2820      Martin Ødegaard    NOR    MF         Arsenal  Premier League  21.0
# 2822        Filip Đuričić    SRB  MFFW        Sassuolo         Serie A  28.0
#
# ...

# %% [markdown]
# ## organize column variables into categories of related stats

# %%
STANDARD_stats_COLUMNS = list(STANDARD_stats_df.columns
                             )
STANDARD_stats_COLUMNS
# Out:
# ['Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Comp',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Gls',
#  'Ast',
#  'G-PK',
#  'PK',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Gls_per90',
#  'Ast_per90',
#  'G+A_per90',
#  'G-PK_per90',
#  'G+A-PK_per90',
#  'xG',
#  'npxG',
#  'xA',
#  'npxG+xA',
#  'xG_per90',
#  'xA_per90',
#  'xG+xA_per90',
#  'npxG_per90',
#  'npxG+xA_per90',
#  'Name_no_spec_chars']

# %%
demographic_vars = ['Nation',
                    'Pos',
                    'Squad',
                    'Comp',
                    'Age',
                    'Born'
                   ]
demographic_vars
# Out:
# ['Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born']

# %%
playing_time_vars = ['MP',
                     'Starts',
                     'Min',
                     '90s'
                    ]
playing_time_vars
# Out:
# ['MP', 'Starts', 'Min', '90s']

# %%
goal_contribution_vars = ['Gls',
                          'Ast',
                          'G-PK',
                          'PK',
                          'PKatt'
                         ]
goal_contribution_vars
# Out:
# ['Gls', 'Ast', 'G-PK', 'PK', 'PKatt']

# %%
goal_contrib_vars_PER_90 = ['Gls_per90',
                             'Ast_per90',
                             'G+A_per90',
                             'G-PK_per90',
                             'G+A-PK_per90'
                            ]
goal_contrib_vars_PER_90
# Out:
# ['Gls_per90', 'Ast_per90', 'G+A_per90', 'G-PK_per90', 'G+A-PK_per90']

# %%
expected_goal_contrib_vars = ['xG',
                              'npxG',
                              'xA',
                              'npxG+xA'
                             ]
expected_goal_contrib_vars
# Out:
# ['xG', 'npxG', 'xA', 'npxG+xA']

# %%
xG_and_xA_vars_PER_90 = ['xG_per90',
                         'xA_per90',
                         'xG+xA_per90',
                         'npxG_per90',
                         'npxG+xA_per90'
                        ]
xG_and_xA_vars_PER_90
# Out:
# ['xG_per90', 'xA_per90', 'xG+xA_per90', 'npxG_per90', 'npxG+xA_per90']

# %% [markdown]
# # NOW organize ROWS into GROUPS:
#
# ## ...first by LEAGUE...
#
# ## ...and then by POSITION
#
# ### Once all rows have already been sorted into their corresponding groups once, the results of this part can then be reused for each of the subsequent six CSV files remaining

# %%
LEAGUE_group_value_counts = (STANDARD_stats_df["Comp"]
                             
                             .value_counts()
                             
                             .reset_index(name = 'Distinct_Value_Counts')
                             
                             .rename(columns = {'index':'League_Name'})
                               
#                              .sort_values('Distinct_Value_Counts')
                            )
LEAGUE_group_value_counts
# Out:
#       League_Name  Distinct_Value_Counts
# 0         La Liga                    416
# 1         Serie A                    408
# 2         Ligue 1                    399
# 3  Premier League                    392
# 4      Bundesliga                    347

# %%
POSITION_group_value_counts = (STANDARD_stats_df["Pos"]
                               
                               .value_counts()
                               
                               .reset_index(name = 'Distinct_Value_Counts')
                               
                               .rename(columns = {'index':'Position_Group'})
                              )

POSITION_group_value_counts
# Out:
#   Position_Group  Distinct_Value_Counts
# 0             DF                    695
# 1             MF                    395
# 2             FW                    249
# 3           FWMF                    200
# 4           MFFW                    165
# 5             GK                    132
# 6           DFMF                     55
# 7           MFDF                     45
# 8           DFFW                     15
# 9           FWDF                     11

# %%
multi_position_groups_list = [
                              'FWMF',
                              'MFFW',
                              
                              'DFMF',
                              'MFDF',
                              
                              'DFFW',
                              'FWDF'
                             ]
multi_position_groups_list
# Out:
# ['FWMF', 'MFFW', 'DFMF', 'MFDF', 'DFFW', 'FWDF']

# %%
multi_POSITION_players_df = STANDARD_stats_df[
                                              STANDARD_stats_df[
                                                                "Pos"
                                                              #      ] 
                                                              #        in
                                                              #           multi_position_groups_list
                                                               
                                                               ].isin(
                                                                      multi_position_groups_list
                                                                     )
                                             ]
multi_POSITION_players_df
# Out:
#                     Player Nation   Pos            Squad            Comp  \
# 7              Charles Abi    FRA  FWMF    Saint-Étienne         Ligue 1
# 18             Tyler Adams    USA  DFMF       RB Leipzig      Bundesliga
# 25    Martin Agirregabiria    ESP  DFMF           Alavés         La Liga
# 30           Sergio Agüero    ARG  FWMF  Manchester City  Premier League
# 31           Ruben Aguilar    FRA  DFFW           Monaco         Ligue 1
# ...                    ...    ...   ...              ...             ...
# 2804          Arber Zeneli    KVX  MFFW            Reims         Ligue 1
# 2807         Mehdi Zerkane    ALG  MFFW         Bordeaux         Ligue 1
# 2813          Hakim Ziyech    MAR  FWMF          Chelsea  Premier League
# 2818          Steven Zuber    SUI  DFMF   Eint Frankfurt      Bundesliga
# 2822         Filip Đuričić    SRB  MFFW         Sassuolo         Serie A
#
#        Age    Born  MP  Starts   Min  ...   xG  npxG   xA  npxG+xA  xG_per90  \
# ...

# %% [markdown]
# # NOTE TO SELF
#
# .
#
# ### FBref's methodology for producing their "scouting report pages" is explained at this link:
#
# https://fbref.com/en/about/scouting-reports-explained#minutes
#
# .
#
# ### That explanation included some important takeaways:

# %% [markdown]
# # FBref methodology  - Takeaway (1)
#
# # "Position Sets"
#
# .
#
# ## Players are grouped into SIX different "position sets":
#
# .
#
# ### GOALKEEPERS
#
# .
#
# ### CENTER BACKS
#
# .
#
# ### FULLBACKS
#
# .
#
# ### MIDFIELDERS
#
# .
#
# ### ATTACKING MIDS and WINGERS
#
# .
#
# ### FORWARDS
#
# (...basically just for STRIKERS...???)
#
# .

# %% [markdown]
# # FBref methodology  - Takeaway (2)
#
# # "Comparison Pools"
#
# .
#
# ## Comparison pools are groups of players in each position set who are used when calculating percentiles.
#
# .
#
# ## To be included in a comparison pool, players need to reach a minimum number of minutes played at that position.
#
# #### These minimums have been set to balance...
#
# - ...the need to ensure that only players with an adequate amount of playing time are included...
#
# - ...but also so that there are enough qualified players in the pool.
#
# .
#
# ### Specifically, for all of the Big Five leagues, the magic number currently for that "minimum" requirement...
#
# ## ...excludes any players who have NOT yet played at least 450 minutes
#
# .
#
# https://fbref.com/en/about/scouting-reports-explained#minutes
#
# .
#
# ### Separating all Midfielders into four different categories...
#
# - ...Defensive...
#
# - ...Central...
#
# - ...Attacking...
#
# - ...and Wide...
#
# ### ...caused each resulting comparison pool to include too few players.
#
# .
#
# ### Instead, the people at FBref made the following important decisions:
#
# .
#
# ## the "position set" for "Midfielders" combines Defensive, Central and Wide Midfielders
#
# .
#
# ## a separate "position set" exists for Attacking Midfielders and Wingers
#
# .
#
# ## the "position set" for "Fullbacks" similarly includes Wingbacks
#
# .

# %%
messi_row_check = multi_POSITION_players_df[
                                            multi_POSITION_players_df["Player"
                                                                      
                                                                     ] == "Lionel Messi"
                                           
                                           ]

messi_row_check
# Out:
#             Player Nation   Pos      Squad     Comp   Age    Born  MP  Starts  \
# 1724  Lionel Messi    ARG  FWMF  Barcelona  La Liga  33.0  1987.0  35      33
#
#        Min  ...    xG  npxG    xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  \
# 1724  3023  ...  23.6  19.5  10.8     30.3       0.7      0.32         1.03
#
#       npxG_per90  npxG+xA_per90  Name_no_spec_chars
# 1724        0.58            0.9        Lionel Messi
#
# [1 rows x 33 columns]

# %% [markdown]
# # ...apparently perfect SPELLING matters:
#
# .

# %%
perisic_row = multi_POSITION_players_df[
                                        multi_POSITION_players_df["Player"
                                                                 
                                                                 ] == "Ivan Perisic"
                                       ]
perisic_row
# Out:
# Empty DataFrame
# Columns: [Player, Nation, Pos, Squad, Comp, Age, Born, MP, Starts, Min, 90s, Gls, Ast, G-PK, PK, PKatt, CrdY, CrdR, Gls_per90, Ast_per90, G+A_per90, G-PK_per90, G+A-PK_per90, xG, npxG, xA, npxG+xA, xG_per90, xA_per90, xG+xA_per90, npxG_per90, npxG+xA_per90, Name_no_spec_chars]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# .
#
# ## ^ note how it failed without the correct "š" and "ć"
#
# .
#
# ## also note that it did NOT produce an error message...
#
# ## ...instead returned empty DF with same columns but 0 rows
#
# .

# %%
perisic_row = multi_POSITION_players_df[
                                        multi_POSITION_players_df["Player"
                                                                 
                                                                 ] == "Ivan Perišić"
                                       ]
perisic_row
# Out:
#             Player Nation   Pos  Squad     Comp   Age    Born  MP  Starts  \
# 2065  Ivan Perišić    CRO  DFFW  Inter  Serie A  31.0  1989.0  32      20
#
#        Min  ...   xG  npxG   xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  \
# 2065  1795  ...  4.4   4.4  4.5      8.9      0.22      0.22         0.44
#
#       npxG_per90  npxG+xA_per90  Name_no_spec_chars
# 2065        0.22           0.44        Ivan Perisic
#
# [1 rows x 33 columns]

# %%
hybrid_position_counts_per_league = (
                                     multi_POSITION_players_df[
                                                               "Comp"
                                                              ]
                                     .value_counts()
                                     
                                     .reset_index(
                                                  name = 'Distinct_Value_Counts'
                                                 )
                                     .rename(
                                             columns = {
                                                        'index':'League_Name'
                                                       }
                                            )
                                    )
hybrid_position_counts_per_league
# Out:
#       League_Name  Distinct_Value_Counts
# 0      Bundesliga                    112
# 1         La Liga                    110
# 2         Ligue 1                    109
# 3  Premier League                     90
# 4         Serie A                     70

# %% [markdown]
# # now FILTER out the 3 most important rows...
#
# # ...for Eriksen, Luis Alberto, and Çalhanoğlu

# %%
# eriksen_row = multi_POSITION_players_df[
#                                         multi_POSITION_players_df["Player"

eriksen_row = STANDARD_stats_df[
                                 STANDARD_stats_df[
                                                   "Player"

                                                  ] == "Christian Eriksen"
                               ]
eriksen_row
# Out:
#                 Player Nation Pos  Squad     Comp   Age    Born  MP  Starts  \
# 821  Christian Eriksen    DEN  MF  Inter  Serie A  28.0  1992.0  26      17
#
#       Min  ...   xG  npxG   xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  \
# 821  1385  ...  1.7   1.7  2.6      4.3      0.11      0.17         0.28
#
#      npxG_per90  npxG+xA_per90  Name_no_spec_chars
# 821        0.11           0.28   Christian Eriksen
#
# [1 rows x 33 columns]

# %%
alberto_row = STANDARD_stats_df[STANDARD_stats_df["Player"

                                                 ] == "Luis Alberto"
                               ]
alberto_row
# Out:
#           Player Nation Pos  Squad     Comp   Age    Born  MP  Starts   Min  \
# 55  Luis Alberto    ESP  MF  Lazio  Serie A  27.0  1992.0  34      33  2618
#
#     ...   xG  npxG   xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  npxG_per90  \
# 55  ...  5.5   5.3  8.2     13.5      0.19      0.28         0.47        0.18
#
#     npxG+xA_per90  Name_no_spec_chars
# 55           0.46        Luis Alberto
#
# [1 rows x 33 columns]

# %%
calhanoglu_row = STANDARD_stats_df[
                                   STANDARD_stats_df[
                                                     "Player"
                                                    
                                                    ] == "Hakan Çalhanoğlu"
                                  ]
calhanoglu_row
# Out:
#                Player Nation   Pos  Squad     Comp   Age    Born  MP  Starts  \
# 421  Hakan Çalhanoğlu    TUR  MFFW  Milan  Serie A  26.0  1994.0  33      30
#
#       Min  ...   xG  npxG   xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  \
# 421  2614  ...  5.5   4.8  8.8     13.5      0.19       0.3         0.49
#
#      npxG_per90  npxG+xA_per90  Name_no_spec_chars
# 421        0.16           0.47    Hakan Calhanoglu
#
# [1 rows x 33 columns]

# %% [markdown]
# # NOTE to self:
#
# ## Eriksen and Alberto both simple, with "Pos" = "MF"
#
# ## ...however, Çalhanoğlu listed as hybrid "Pos" = "MFFW"

# %% [markdown]
# .
#
# # Initial Plan for Approaching Next Step:
#
# .
#
# ## start by just getting the averages/percentiles
#
# ## ...for each stat, only using rows listed as "MF"
#
# .
#
# ### the main point of this analysis is to get a sense of how well Çalhanoğlu can adjust to the deeper LCM role, as opposed to his usual "trequartista" CAM role
#
# .
#
# ### comparing his CAM stats to everyone else's ACTUAL midfielder stats should of course be taken with a grain of salt as a result...
#
# ### ...that being said, it's still the most logical way to at least start out
#
# .

# %%
#                                 | STANDARD_stats_df["Player"

#                                                  ] == "Luis Alberto"

# %%
MF_standard_stats_Big_5 =  STANDARD_stats_df[
                                             (STANDARD_stats_df["Pos"
                                                               
                                                               ] == "MF"
                                             )  |   # "or"
                                             
                                             (STANDARD_stats_df["Player"
                                                               
                                                               ] == "Hakan Çalhanoğlu"
                                             )
                                            ]
MF_standard_stats_Big_5
# Out:
#                           Player Nation Pos          Squad            Comp  \
# 5                    Mehdi Abeid    ALG  MF         Nantes         Ligue 1
# 6                Laurent Abergel    FRA  MF        Lorient         Ligue 1
# 22                   Yacine Adli    FRA  MF       Bordeaux         Ligue 1
# 26                 Lucien Agoume    FRA  MF         Spezia         Serie A
# 33                Matteo Ahlinvi    BEN  MF          Nîmes         Ligue 1
# ...                          ...    ...  ..            ...             ...
# 2794  Andre-Frank Zambo Anguissa    CMR  MF         Fulham  Premier League
# 2795           Niccolò Zanellato    ITA  MF        Crotone         Serie A
# 2809             Piotr Zieliński    POL  MF         Napoli         Serie A
# 2819            Martín Zubimendi    ESP  MF  Real Sociedad         La Liga
# 2820             Martin Ødegaard    NOR  MF        Arsenal  Premier League
#
# ...

# %% [markdown]
# # now create separate DF with RANKS and...
#
# # ...PERCENTILES for each corresponding column

# %%
MF_big_5_std_NUMERICAL_stats = MF_standard_stats_Big_5.loc[:,
                                                           
                                                           'Age' : 'npxG+xA_per90'
                                                          ]
MF_big_5_std_NUMERICAL_stats
# Out:
#        Age    Born  MP  Starts   Min   90s  Gls  Ast  G-PK  PK  ...  \
# 5     27.0  1992.0  18      15  1320  14.7    0    0     0   0  ...
# 6     27.0  1993.0  38      32  2963  32.9    3    1     3   0  ...
# 22    20.0  2000.0  35      25  2418  26.9    2    5     2   0  ...
# 26    18.0  2002.0  12       9   800   8.9    0    0     0   0  ...
# 33    21.0  1999.0  20      10   899  10.0    2    0     2   0  ...
# ...    ...     ...  ..     ...   ...   ...  ...  ...   ...  ..  ...
# 2794  24.0  1995.0  36      29  2587  28.7    0    3     0   0  ...
# 2795  22.0  1998.0  27      18  1637  18.2    1    1     1   0  ...
# 2809  26.0  1994.0  36      32  2523  28.0    8   10     8   0  ...
# 2819  21.0  1999.0  31      17  1882  20.9    0    0     0   0  ...
# 2820  21.0  1998.0  14       9   866   9.6    1    2     1   0  ...
#
#       G+A-PK_per90   xG  npxG   xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  \
# ...

# %%
MF_big_5_std_NUMERICAL_stats.insert(
                                    loc = 0,
                                    
                                    column = 'Player',
                                    
                                    value = MF_standard_stats_Big_5[
                                                                    'Player'
                                                                   ]
                                   )
MF_big_5_std_NUMERICAL_stats
# Out:
#                           Player   Age    Born  MP  Starts   Min   90s  Gls  \
# 5                    Mehdi Abeid  27.0  1992.0  18      15  1320  14.7    0
# 6                Laurent Abergel  27.0  1993.0  38      32  2963  32.9    3
# 22                   Yacine Adli  20.0  2000.0  35      25  2418  26.9    2
# 26                 Lucien Agoume  18.0  2002.0  12       9   800   8.9    0
# 33                Matteo Ahlinvi  21.0  1999.0  20      10   899  10.0    2
# ...                          ...   ...     ...  ..     ...   ...   ...  ...
# 2794  Andre-Frank Zambo Anguissa  24.0  1995.0  36      29  2587  28.7    0
# 2795           Niccolò Zanellato  22.0  1998.0  27      18  1637  18.2    1
# 2809             Piotr Zieliński  26.0  1994.0  36      32  2523  28.0    8
# 2819            Martín Zubimendi  21.0  1999.0  31      17  1882  20.9    0
# 2820             Martin Ødegaard  21.0  1998.0  14       9   866   9.6    1
#
# ...

# %%
MF_big_5_std_NUMERICAL_stats.set_index(
                                       'Player',
                                       
                                       inplace = True
                                      )
MF_big_5_std_NUMERICAL_stats
# Out:
#                              Age    Born  MP  Starts   Min   90s  Gls  Ast  \
# Player
# Mehdi Abeid                 27.0  1992.0  18      15  1320  14.7    0    0
# Laurent Abergel             27.0  1993.0  38      32  2963  32.9    3    1
# Yacine Adli                 20.0  2000.0  35      25  2418  26.9    2    5
# Lucien Agoume               18.0  2002.0  12       9   800   8.9    0    0
# Matteo Ahlinvi              21.0  1999.0  20      10   899  10.0    2    0
# ...                          ...     ...  ..     ...   ...   ...  ...  ...
# Andre-Frank Zambo Anguissa  24.0  1995.0  36      29  2587  28.7    0    3
# Niccolò Zanellato           22.0  1998.0  27      18  1637  18.2    1    1
# Piotr Zieliński             26.0  1994.0  36      32  2523  28.0    8   10
# Martín Zubimendi            21.0  1999.0  31      17  1882  20.9    0    0
# Martin Ødegaard             21.0  1998.0  14       9   866   9.6    1    2
#
# ...

# %%
# MF_in_Big_5_std_stat_RANKS = (
#                               MF_standard_stats_Big_5.


MF_in_Big_5_std_stat_RANKS = (MF_big_5_std_NUMERICAL_stats.
                              
                              rank(ascending = 0,
#                                              0 = False
                                   
                                   method = 'min'   # ,
                                   
#                                    pct = True
                                  )
                              
                              .astype(int)
                             )
MF_in_Big_5_std_stat_RANKS
# Out:
#                             Age  Born   MP  Starts  Min  90s  Gls  Ast  G-PK  \
# Player
# Mehdi Abeid                 139   251  331     269  276  273  250  259   239
# Laurent Abergel             139   225    1      39   21   20   63  164    48
# Yacine Adli                 366    19   36     134   98   98   99   28    88
# Lucien Agoume               385     5  383     347  359  359  250  259   239
# Matteo Ahlinvi              346    28  317     340  346  346   99  259    88
# ...                         ...   ...  ...     ...  ...  ...  ...  ...   ...
# Andre-Frank Zambo Anguissa  240   145   19      76   71   71  250   59   239
# Niccolò Zanellato           310    48  204     225  224  224  150  164   141
# Piotr Zieliński             169   180   19      39   87   87   12    4     8
# Martín Zubimendi            346    28  127     238  184  184  250  259   239
# Martin Ødegaard             346    48  368     347  352  352  150  100   141
#
# ...

# %%
MF_big_5_std_stat_PERCENTILES = (MF_big_5_std_NUMERICAL_stats.
                                 
                                 rank(ascending = 1,
#                                              0 = False
                                      
                                      method = 'min',
                                      
                                      pct = True
                                     )
                                 
#                                  .astype(int)
                                )
MF_big_5_std_stat_PERCENTILES
# Out:
#                                  Age      Born        MP    Starts       Min  \
# Player
# Mehdi Abeid                 0.578283  0.308081  0.141414  0.275253  0.305556
# Laurent Abergel             0.578283  0.371212  0.982323  0.863636  0.949495
# Yacine Adli                 0.050505  0.934343  0.863636  0.623737  0.755051
# Lucien Agoume               0.022727  0.977273  0.022727  0.103535  0.093434
# Matteo Ahlinvi              0.080808  0.883838  0.186869  0.128788  0.126263
# ...                              ...       ...       ...       ...       ...
# Andre-Frank Zambo Anguissa  0.323232  0.550505  0.914141  0.770202  0.823232
# Niccolò Zanellato           0.131313  0.810606  0.431818  0.404040  0.436869
# Piotr Zieliński             0.484848  0.436869  0.914141  0.863636  0.782828
# Martín Zubimendi            0.080808  0.883838  0.641414  0.343434  0.537879
# Martin Ødegaard             0.080808  0.810606  0.058081  0.103535  0.113636
#
# ...

# %% [markdown]
# # now extract two sub-DF's --> 3 rows each
#
# .
#
# # ...to see the RANKS first and then the...
#
# .
#
# # ...PERCENTILES in each column variable...
#
# .
#
# # ...for Eriksen, Alberto, and Çalhanoğlu

# %%
playmaking_artists = [
                      "Christian Eriksen",
                      
                      "Luis Alberto",
                      
                      "Hakan Çalhanoğlu"
                     ]
playmaking_artists
# Out:
# ['Christian Eriksen', 'Luis Alberto', 'Hakan Çalhanoğlu']

# %% [markdown]
# # first get their RANKS from...
#
#
#
# # "MF_in_Big_5_std_stat_RANKS"

# %%
# playmaking_artist_RANKS = MF_in_Big_5_std_stat_RANKS[MF_in_Big_5_std_stat_RANKS["Player"                                                                               
#                                                                                ].isin(playmaking_artists)
#                                                     ]
# playmaking_artist_RANKS

# %% [markdown]
# ## NOTE to self:
#
# .
#
# ### the ABOVE code chunk did NOT work, because the...
#
# ### ..."Player" column was set to be the INDEX now
#
# .
#
# ### the BELOW code chunk actually DID work
#
# .
#
# #### ...however, I wanted to try reformatting in a separate cell in order to make it...
#
# #### ...more readable, but without the risk of messing up what had actually worked
#
# .

# %%
# playmaking_artist_RANKS = MF_in_Big_5_std_stat_RANKS[MF_in_Big_5_std_stat_RANKS.index.isin(playmaking_artists)
#                                                     ]
# playmaking_artist_RANKS

# %%
playmaking_artist_RANKS = (
                           MF_in_Big_5_std_stat_RANKS[
                                                      MF_in_Big_5_std_stat_RANKS
                                                      
                                                      .index
                                                      
                                                      .isin(
                                                            playmaking_artists
                                                           )
                                                     ]
                          )
playmaking_artist_RANKS
# Out:
#                    Age  Born   MP  Starts  Min  90s  Gls  Ast  G-PK  PK  ...  \
# Player                                                                   ...
# Luis Alberto       139   251   56      28   65   64    8  100     4  43  ...
# Hakan Çalhanoğlu   169   180   75      66   68   68   46    7    48  24  ...
# Christian Eriksen  109   251  227     238  264  264   63  259    48  43  ...
#
#                    G+A-PK_per90   xG  npxG  xA  npxG+xA  xG_per90  xA_per90  \
# Player
# Luis Alberto                 30   20    13   6        8        35         8
# Hakan Çalhanoğlu             27   20    17   5        8        35         5
# Christian Eriksen           113  132   119  79      100        98        40
#
#                    xG+xA_per90  npxG_per90  npxG+xA_per90
# Player
# Luis Alberto                10          31              9
# Hakan Çalhanoğlu             9          35              8
# Christian Eriksen           64          77             56
#
# ...

# %% [markdown]
# # then get the PERCENTILES from...
#
#
#
# # "MF_big_5_std_stat_PERCENTILES"
#
# .

# %%
playmaking_artist_PERCENTILES = (MF_big_5_std_stat_PERCENTILES[MF_big_5_std_stat_PERCENTILES
                                                               
                                                               .index
                                                               
                                                               .isin(playmaking_artists
                                                                    )
                                                              ]
                                )
playmaking_artist_PERCENTILES
# Out:
#                         Age      Born        MP    Starts       Min       90s  \
# Player
# Luis Alberto       0.578283  0.308081  0.815657  0.906566  0.838384  0.833333
# Hakan Çalhanoğlu   0.484848  0.436869  0.747475  0.813131  0.830808  0.828283
# Christian Eriksen  0.654040  0.308081  0.404040  0.343434  0.335859  0.335859
#
#                         Gls       Ast      G-PK        PK  ...  G+A-PK_per90  \
# Player                                                     ...
# Luis Alberto       0.974747  0.590909  0.984848  0.002525  ...      0.921717
# Hakan Çalhanoğlu   0.845960  0.972222  0.782828  0.896465  ...      0.934343
# Christian Eriksen  0.755051  0.002525  0.782828  0.002525  ...      0.694444
#
#                          xG      npxG        xA   npxG+xA  xG_per90  xA_per90  \
# Player
# Luis Alberto       0.949495  0.969697  0.987374  0.979798  0.891414  0.977273
# Hakan Çalhanoğlu   0.949495  0.959596  0.989899  0.979798  0.891414  0.984848
# ...

# %% [markdown]
# # now TRANSPOSE both mini-DataFrames
#
# .

# %%
RANKS_transposed = playmaking_artist_RANKS.transpose()

RANKS_transposed
# Out:
# Player         Luis Alberto  Hakan Çalhanoğlu  Christian Eriksen
# Age                     139               169                109
# Born                    251               180                251
# MP                       56                75                227
# Starts                   28                66                238
# Min                      65                68                264
# 90s                      64                68                264
# Gls                       8                46                 63
# Ast                     100                 7                259
# G-PK                      4                48                 48
# PK                       43                24                 43
# PKatt                    47                29                 47
# CrdY                    142               199                346
# CrdR                     71                71                 71
# ...

# %%
PERCENTILES_transposed = playmaking_artist_PERCENTILES.transpose()

PERCENTILES_transposed
# Out:
# Player         Luis Alberto  Hakan Çalhanoğlu  Christian Eriksen
# Age                0.578283          0.484848           0.654040
# Born               0.308081          0.436869           0.308081
# MP                 0.815657          0.747475           0.404040
# Starts             0.906566          0.813131           0.343434
# Min                0.838384          0.830808           0.335859
# 90s                0.833333          0.828283           0.335859
# Gls                0.974747          0.845960           0.755051
# Ast                0.590909          0.972222           0.002525
# G-PK               0.984848          0.782828           0.782828
# PK                 0.002525          0.896465           0.002525
# PKatt              0.002525          0.886364           0.002525
# CrdY               0.502525          0.363636           0.050505
# CrdR               0.002525          0.002525           0.002525
# ...

# %% [markdown]
# ## the following CODE chunk, copied from...
#
#
#
# ### my latest draft in the "Oeuvrenalysis" folder...
#
#
#
# ### ...successfully produced a FACET GRID with...
#
#
#
# ### ...every single variable for all three players!!!
#
# .

# %%
# ax = Stats_df.plot.barh(
#                         subplots = True,
                        
# #                         use_index = False
                        
#                         layout = (25,    # rows
#                                   1    # columns
#                                  ),
                        
#                         figsize = (5,
#                                    125
#                                   ),
                        
#                         sharex = False
                        
#                         #
                        
#                         #
#                        )

# %% [markdown]
# .
#
# ## ...HOWEVER, that was only possible/practical because...
#
#
#
# ## ...it used just THREE players... as opposed to 396 players
#
# .

# %%
MF_standard_stats_Big_5
# Out:
#                           Player Nation Pos          Squad            Comp  \
# 5                    Mehdi Abeid    ALG  MF         Nantes         Ligue 1
# 6                Laurent Abergel    FRA  MF        Lorient         Ligue 1
# 22                   Yacine Adli    FRA  MF       Bordeaux         Ligue 1
# 26                 Lucien Agoume    FRA  MF         Spezia         Serie A
# 33                Matteo Ahlinvi    BEN  MF          Nîmes         Ligue 1
# ...                          ...    ...  ..            ...             ...
# 2794  Andre-Frank Zambo Anguissa    CMR  MF         Fulham  Premier League
# 2795           Niccolò Zanellato    ITA  MF        Crotone         Serie A
# 2809             Piotr Zieliński    POL  MF         Napoli         Serie A
# 2819            Martín Zubimendi    ESP  MF  Real Sociedad         La Liga
# 2820             Martin Ødegaard    NOR  MF        Arsenal  Premier League
#
# ...

# %%
playmaking_artist_STATS = MF_standard_stats_Big_5[
                                                  MF_standard_stats_Big_5[
                                                                          "Player"
                                                                          
                                                                         ].isin(
                                                                                playmaking_artists
                                                                               )
                                                 ]
playmaking_artist_STATS
# Out:
#                 Player Nation   Pos  Squad     Comp   Age    Born  MP  Starts  \
# 55        Luis Alberto    ESP    MF  Lazio  Serie A  27.0  1992.0  34      33
# 421   Hakan Çalhanoğlu    TUR  MFFW  Milan  Serie A  26.0  1994.0  33      30
# 821  Christian Eriksen    DEN    MF  Inter  Serie A  28.0  1992.0  26      17
#
#       Min  ...   xG  npxG   xA  npxG+xA  xG_per90  xA_per90  xG+xA_per90  \
# 55   2618  ...  5.5   5.3  8.2     13.5      0.19      0.28         0.47
# 421  2614  ...  5.5   4.8  8.8     13.5      0.19      0.30         0.49
# 821  1385  ...  1.7   1.7  2.6      4.3      0.11      0.17         0.28
#
#      npxG_per90  npxG+xA_per90  Name_no_spec_chars
# 55         0.18           0.46        Luis Alberto
# 421        0.16           0.47    Hakan Calhanoglu
# 821        0.11           0.28   Christian Eriksen
#
# [3 rows x 33 columns]

# %%
playmaking_artist_STATS.set_index(
                                  'Player',
                                  
                                  inplace = True
                                 )

# %%
playmaking_artists_TRANSPOSED = playmaking_artist_STATS.transpose()

playmaking_artists_TRANSPOSED
# Out:
# Player              Luis Alberto  Hakan Çalhanoğlu  Christian Eriksen
# Nation                       ESP               TUR                DEN
# Pos                           MF              MFFW                 MF
# Squad                      Lazio             Milan              Inter
# Comp                     Serie A           Serie A            Serie A
# Age                           27                26                 28
# Born                        1992              1994               1992
# MP                            34                33                 26
# Starts                        33                30                 17
# Min                         2618              2614               1385
# 90s                         29.1                29               15.4
# Gls                            9                 4                  3
# Ast                            2                 9                  0
# ...

# %%
ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5
                )


# ax = sns.swarmplot(x = "xA_per90",
                   
#                    y = "Comp",
                   
#                    data = MF_standard_stats_Big_5
#                   )

# %%
ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 10.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
ax = sns.swarmplot(x = "Comp",
                   
                   y = "xA_per90",
                   
                   data = MF_standard_stats_Big_5
                  )
# Out:
# /Users/interpool/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize = (15,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )

# %%
plt.figure(figsize = (15,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


plt.ylabel = None


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
plt.figure(figsize = (15,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


plt.ylabel = ('')


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
plt.figure(figsize = (15,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax.set(ylabel = None)


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(figsize = (15,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax.set(xlabel = None
      )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax.set(ylabel = None
      )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax = sns.swarmplot(
                   x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


# ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")


plt.title("xA per 90 - Big 5 league midfielders (20/21 season)"
         )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax.set(xlabel = None)

ax.set(ylabel = None)


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      12
                     )
          )
#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(
                   x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


# ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")


plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",
          
#           loc = 'left',

          fontsize = 20,
          
#           alpha = 0.9,
          
#           style = 'italic',

#           color = 'yellow'
         )


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


ax.set(xlabel = None)

ax.set(ylabel = None)


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5,
                   
                   color = "0.9"          # "0.2" (almost black)
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")



plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5,
                 
                 saturation = 0.97
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5,
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   size = 7
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")



plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      12
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5,
                 
                 saturation = 0.97,
                 
                 linewidth = 5
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5,
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   size = 7
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")



plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5,
                 
                 
#                  color = "goldenrod",
                 
                 saturation = 0.97,
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   data = MF_standard_stats_Big_5,
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   size = 6
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# ax.set(title = "xA per 90 - Big 5 league midfielders (20/21 season)")



plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5,
                 
                 
#                  color = "goldenrod",
                 
                 
                 saturation = 0.35,    # 0.97,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   
                   
                   size = 6
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   
                   
                   size = 6
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   
                   
                   size = 6
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,
                 
                 fliersize = 10,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
                   
                   
                   size = 6
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 0.025,    # 0.1,
                 
                 
                 
                 linewidth = 4
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
#                    color = "0.97",          # "0.2" (almost black)
                   
                   color = "0.8",
                   
                   edgecolor = "yellow",
                   
                   
                   size = 6.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 0.025,    # 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
#                    color = "0.97",          # "0.2" (almost black)
                   
#                    color =  "yellow",
                   
                   color =  "lawngreen",
                   
                   
                   size = 5.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,
                      15
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
#                    color = "0.97",          # "0.2" (almost black)
                   
#                    color =  "yellow",
                   
                   color =  "lawngreen",
                   
                   
                   size = 5.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,     # 15,
                      15     # 20
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
                 saturation = 0.3,    # 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
#                    color = "0.97",          # "0.2" (almost black)
                   
#                    color =  "yellow",    # "limegreen",    # "lawngreen",
                   
                   color = "cyan",
                   
                   
                   size = 5.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,     # 15,
                      15     # 20
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# sns.color_palette("dark")

sns.set_palette("dark")

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
#                  saturation = 0.3,    # 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
#                    color =  "yellow",    # "limegreen",    # "lawngreen",
                   
#                    color = "cyan",
                   
                   
                   size = 5.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,     # 15,
                      15     # 20
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

sns.set_palette("dark",
                
                desat = 0.7
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
#                  saturation = 0.3,    # 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
#                    color =  "yellow",    # "limegreen",    # "lawngreen",
                   
#                    color = "cyan",
                   
                   
                   size = 5.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,     # 15,
                      15     # 20
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# sns.set_palette("dark",

sns.set_palette("deep",
                
                desat = 0.7
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# red_diamond = {"markerfacecolor" : 'r',
               
#                "marker" : 'd'
#               }


red_square = {"markerfacecolor" : 'r',
              "marker" : 's'
             }


#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,     #  _diamond,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 
                 
#                  color = "goldenrod",
                 
                 
#                  saturation = 0.35,    # 0.97,
                 
#                  saturation = 0.3,    # 0.1,
                 
                 
                 
                 linewidth = 5
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",          # "0.2" (almost black)
                   
#                    color =  "yellow",    # "limegreen",    # "lawngreen",
                   
#                    color = "cyan",
                   
                   
                   size = 5.5
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 20,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]

# %%
plt.figure(
           figsize = (
                      12,     # 15,
                      17     # 20
                     )
          )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

sns.set_palette("deep",
                
                desat = 0.5
               )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

red_square = {
              "markerfacecolor" : 'r',
              
              "marker" : 's'
             }

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.boxplot(x = "xA_per90",
                 
                 y = "Comp",
                 
                 
                 data = MF_standard_stats_Big_5,
                 
                 
                 flierprops = red_square,
                 
                 fliersize = 8,
                 
                 
                 notch = True,
                 

                 linewidth = 7
                 
                 #
                )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax = sns.swarmplot(x = "xA_per90",
                   
                   y = "Comp",
                   
                   
                   data = MF_standard_stats_Big_5,
                   
                   
                   
                   color = "0.97",
                   
                   
                   size = 6
                  )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

plt.title(
          "xA per 90 - Big 5 league midfielders (20/21 season)",

          fontsize = 21,
          
#           loc = 'left',
#           alpha = 0.9,
#           style = 'italic',
#           color = 'yellow'
         )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

ax.set(
       xlabel = None
      )

ax.set(
       ylabel = None
      )

#- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# [Text(0, 0.5, '')]
