# %%
import pandas as pd
#~~~~~~~~~~~~~~~~~~~~
import numpy as np

# %%
import os.path
#~~~~~~~~~~~~~~~~~~~~~~
from PIL import Image

# %%
from adjustText import adjust_text

# %%
import matplotlib.pyplot as plt
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import seaborn as sns
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %matplotlib inline

# %%
plt.style.use(
              [
               'bmh',
               'dark_background'
              ]
             )

# %%
#sns.set_context('notebook')
#sns.set_context('paper')
#sns.set_context('talk')
#sns.set_context('poster')

sns.set_context(
                'paper',
                font_scale = 1.8
               )

fig, ax = plt.subplots()

# %% [markdown]
# # PART (1) — LOAD from CSV to DataFrame

# %%
data_folder_path = ('~/SBNation_Articles_Soccer_Data/' +
                     'Player_Comparisons/' +
                     'Oeuvrenalysis_Calhanoglu/' +
                     'DATA_playmakers_20_21/')
data_folder_path
# Out:
# '~/SBNation_Articles_Soccer_Data/Player_Comparisons/Oeuvrenalysis_Calhanoglu/DATA_playmakers_20_21/'

# %%
file_path = (data_folder_path +
             'Standard_Stats_20_21.csv')
file_path
# Out:
# '~/SBNation_Articles_Soccer_Data/Player_Comparisons/Oeuvrenalysis_Calhanoglu/DATA_playmakers_20_21/Standard_Stats_20_21.csv'

# %%
Standard_Stats_df = pd.read_csv(file_path)

# %%
Standard_Stats_df
# Out:
#          Player     Span Nation   Pos  Squad  MP  Starts   Min   90s  Gls  \
# 0       Eriksen  2020-21    DEN    MF  Inter  26      17  1385  15.4    3
# 1  Luis Alberto  2020-21    ESP    MF  Lazio  34      33  2618  29.1    9
# 2    Çalhanoğlu  2020-21    TUR  MFFW  Milan  33      30  2614  29.0    4
#
#    ...  G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  \
# 0  ...           0.19  1.7   1.7  2.6      4.3       0.11       0.17
# 1  ...           0.38  5.5   5.3  8.2     13.5       0.19       0.28
# 2  ...           0.41  5.5   4.8  8.8     13.5       0.19       0.30
#
#    xG+xA_per_90  npxG_per_90  npxG+xA_per_90
# 0          0.28         0.11            0.28
# 1          0.47         0.18            0.46
# 2          0.49         0.16            0.47
#
# [3 rows x 30 columns]

# %%
columns_list = list(
                    Standard_Stats_df.columns
                   )
columns_list
# Out:
# ['Player',
#  'Span',
#  'Nation',
#  'Pos',
#  'Squad',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Gls',
#  'Ast',
#  'G-PK',
#  'PK',
#  'PKatt',
#  'CrdY',
#  'CrdR',
#  'Gls_per_90',
#  'Ast_per_90',
#  'G+A_per_90',
#  'G-PK_per_90',
#  'G+A-PK_per_90',
#  'xG',
#  'npxG',
#  'xA',
#  'npxG+xA',
#  'xG_per_90',
#  'xA_per_90',
#  'xG+xA_per_90',
#  'npxG_per_90',
#  'npxG+xA_per_90']

# %%
Stat_Numbers = Standard_Stats_df.loc[:,
                                     'MP':'npxG+xA_per_90'
                                    ]
Stat_Numbers
# Out:
#    MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  CrdY  ...  \
# 0  26      17  1385  15.4    3    0     3   0      0     1  ...
# 1  34      33  2618  29.1    9    2     9   0      0     5  ...
# 2  33      30  2614  29.0    4    9     3   1      1     4  ...
#
#    G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  xG+xA_per_90  \
# 0           0.19  1.7   1.7  2.6      4.3       0.11       0.17          0.28
# 1           0.38  5.5   5.3  8.2     13.5       0.19       0.28          0.47
# 2           0.41  5.5   4.8  8.8     13.5       0.19       0.30          0.49
#
#    npxG_per_90  npxG+xA_per_90
# 0         0.11            0.28
# 1         0.18            0.46
# 2         0.16            0.47
#
# [3 rows x 25 columns]

# %%
#Stats_df = 

Stat_Numbers.insert(loc = 0,
                               column = 'Player',
                               value = Standard_Stats_df['Player']
                              )

# %%
Stat_Numbers
# Out:
#          Player  MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  ...  \
# 0       Eriksen  26      17  1385  15.4    3    0     3   0      0  ...
# 1  Luis Alberto  34      33  2618  29.1    9    2     9   0      0  ...
# 2    Çalhanoğlu  33      30  2614  29.0    4    9     3   1      1  ...
#
#    G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  xG+xA_per_90  \
# 0           0.19  1.7   1.7  2.6      4.3       0.11       0.17          0.28
# 1           0.38  5.5   5.3  8.2     13.5       0.19       0.28          0.47
# 2           0.41  5.5   4.8  8.8     13.5       0.19       0.30          0.49
#
#    npxG_per_90  npxG+xA_per_90
# 0         0.11            0.28
# 1         0.18            0.46
# 2         0.16            0.47
#
# [3 rows x 26 columns]

# %%
Stats_df = Stat_Numbers

Stats_df
# Out:
#          Player  MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  ...  \
# 0       Eriksen  26      17  1385  15.4    3    0     3   0      0  ...
# 1  Luis Alberto  34      33  2618  29.1    9    2     9   0      0  ...
# 2    Çalhanoğlu  33      30  2614  29.0    4    9     3   1      1  ...
#
#    G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  xG+xA_per_90  \
# 0           0.19  1.7   1.7  2.6      4.3       0.11       0.17          0.28
# 1           0.38  5.5   5.3  8.2     13.5       0.19       0.28          0.47
# 2           0.41  5.5   4.8  8.8     13.5       0.19       0.30          0.49
#
#    npxG_per_90  npxG+xA_per_90
# 0         0.11            0.28
# 1         0.18            0.46
# 2         0.16            0.47
#
# [3 rows x 26 columns]

# %%
Stats_df.set_index('Player',
                   inplace = True
                  )

Stats_df
# Out:
#               MP  Starts   Min   90s  Gls  Ast  G-PK  PK  PKatt  CrdY  ...  \
# Player                                                                 ...
# Eriksen       26      17  1385  15.4    3    0     3   0      0     1  ...
# Luis Alberto  34      33  2618  29.1    9    2     9   0      0     5  ...
# Çalhanoğlu    33      30  2614  29.0    4    9     3   1      1     4  ...
#
#               G+A-PK_per_90   xG  npxG   xA  npxG+xA  xG_per_90  xA_per_90  \
# Player
# Eriksen                0.19  1.7   1.7  2.6      4.3       0.11       0.17
# Luis Alberto           0.38  5.5   5.3  8.2     13.5       0.19       0.28
# Çalhanoğlu             0.41  5.5   4.8  8.8     13.5       0.19       0.30
#
#               xG+xA_per_90  npxG_per_90  npxG+xA_per_90
# Player
# Eriksen               0.28         0.11            0.28
# Luis Alberto          0.47         0.18            0.46
# Çalhanoğlu            0.49         0.16            0.47
#
# [3 rows x 25 columns]

# %% [markdown]
# # PART (2) — identify RANKINGS per column

# %%
Stat_RANKS_df = (Stats_df.rank(ascending = 0,
                              #     '0' = 'False'
                               method = 'min'
                              )
                    .astype(int)
                   )

# %%
Stat_RANKS_df
# Out:
#               MP  Starts  Min  90s  Gls  Ast  G-PK  PK  PKatt  CrdY  ...  \
# Player                                                               ...
# Eriksen        3       3    3    3    3    3     2   2      2     3  ...
# Luis Alberto   1       1    1    1    1    2     1   2      2     1  ...
# Çalhanoğlu     2       2    2    2    2    1     2   1      1     2  ...
#
#               G+A-PK_per_90  xG  npxG  xA  npxG+xA  xG_per_90  xA_per_90  \
# Player
# Eriksen                   3   3     3   3        3          3          3
# Luis Alberto              2   1     1   2        1          1          2
# Çalhanoğlu                1   1     2   1        1          1          1
#
#               xG+xA_per_90  npxG_per_90  npxG+xA_per_90
# Player
# Eriksen                  3            3               3
# Luis Alberto             2            1               2
# Çalhanoğlu               1            2               1
#
# [3 rows x 25 columns]

# %% [markdown]
# # PART (3) — TRANSPOSE both OG and RANKS dataframes

# %%
Stats_Transposed = Stats_df.transpose()

Stats_Transposed
# Out:
# Player          Eriksen  Luis Alberto  Çalhanoğlu
# MP                26.00         34.00       33.00
# Starts            17.00         33.00       30.00
# Min             1385.00       2618.00     2614.00
# 90s               15.40         29.10       29.00
# Gls                3.00          9.00        4.00
# Ast                0.00          2.00        9.00
# G-PK               3.00          9.00        3.00
# PK                 0.00          0.00        1.00
# PKatt              0.00          0.00        1.00
# CrdY               1.00          5.00        4.00
# CrdR               0.00          0.00        0.00
# Gls_per_90         0.19          0.31        0.14
# Ast_per_90         0.00          0.07        0.31
# G+A_per_90         0.19          0.38        0.45
# G-PK_per_90        0.19          0.31        0.10
# G+A-PK_per_90      0.19          0.38        0.41
# xG                 1.70          5.50        5.50
# npxG               1.70          5.30        4.80
# xA                 2.60          8.20        8.80
# npxG+xA            4.30         13.50       13.50
# xG_per_90          0.11          0.19        0.19
# xA_per_90          0.17          0.28        0.30
# xG+xA_per_90       0.28          0.47        0.49
# npxG_per_90        0.11          0.18        0.16
# npxG+xA_per_90     0.28          0.46        0.47

# %%
Ranks_Transposed = Stat_RANKS_df.transpose()

Ranks_Transposed
# Out:
# Player          Eriksen  Luis Alberto  Çalhanoğlu
# MP                    3             1           2
# Starts                3             1           2
# Min                   3             1           2
# 90s                   3             1           2
# Gls                   3             1           2
# Ast                   3             2           1
# G-PK                  2             1           2
# PK                    2             2           1
# PKatt                 2             2           1
# CrdY                  3             1           2
# CrdR                  1             1           1
# Gls_per_90            2             1           3
# Ast_per_90            3             2           1
# G+A_per_90            3             2           1
# G-PK_per_90           2             1           3
# G+A-PK_per_90         3             2           1
# xG                    3             1           1
# npxG                  3             1           2
# xA                    3             2           1
# npxG+xA               3             1           1
# xG_per_90             3             1           1
# xA_per_90             3             2           1
# xG+xA_per_90          3             2           1
# npxG_per_90           3             1           2
# npxG+xA_per_90        3             2           1

# %%
Ranks_Transposed.plot.hist(use_index = True,

                           subplots = True,
                           
                           orientation = 'horizontal',
                           
                           
                           figsize = (11,  # width (inches)
                                      8  # height (also inches)
                                     ),

                           layout = (3,  # number of "rows" for subplots
                                     1  # number of subplot "columns"
                                    ),

                           yticks = (# 0,
                                     1, 2, 3   #  ,
                                     # 4
                                    ),
                           
                           sharex = True,
                           sharey = True,

                           
                           color = ('gold',  #  Eriksen
                                    'aqua',   #  Luis Alberto
                                    'crimson'  #  Calhanoglu
                                   ),
                           
                           title = "Histogram: Each Player's Count per Ranking (All Variables)"
                          )
# Out:
# array([[<AxesSubplot:xlabel='Frequency'>],
#        [<AxesSubplot:xlabel='Frequency'>],
#        [<AxesSubplot:xlabel='Frequency'>]], dtype=object)

# %% [markdown]
# # PART (4) -- JOIN (not "merge" or "concat") STATS df + RANKS df

# %%
stats_and_ranks = Stats_Transposed.join(Ranks_Transposed,
                                        
                                        lsuffix = ' STATS',
                                        
                                        rsuffix = ' RANK'
                                       )
stats_and_ranks
# Out:
# Player          Eriksen STATS  Luis Alberto STATS  Çalhanoğlu STATS  \
# MP                      26.00               34.00             33.00
# Starts                  17.00               33.00             30.00
# Min                   1385.00             2618.00           2614.00
# 90s                     15.40               29.10             29.00
# Gls                      3.00                9.00              4.00
# Ast                      0.00                2.00              9.00
# G-PK                     3.00                9.00              3.00
# PK                       0.00                0.00              1.00
# PKatt                    0.00                0.00              1.00
# CrdY                     1.00                5.00              4.00
# CrdR                     0.00                0.00              0.00
# Gls_per_90               0.19                0.31              0.14
# Ast_per_90               0.00                0.07              0.31
# G+A_per_90               0.19                0.38              0.45
# G-PK_per_90              0.19                0.31              0.10
# G+A-PK_per_90            0.19                0.38              0.41
# xG                       1.70                5.50              5.50
# npxG                     1.70                5.30              4.80
# xA                       2.60                8.20              8.80
# npxG+xA                  4.30               13.50             13.50
# xG_per_90                0.11                0.19              0.19
# xA_per_90                0.17                0.28              0.30
# xG+xA_per_90             0.28                0.47              0.49
# npxG_per_90              0.11                0.18              0.16
# npxG+xA_per_90           0.28                0.46              0.47
#
# Player          Eriksen RANK  Luis Alberto RANK  Çalhanoğlu RANK
# MP                         3                  1                2
# Starts                     3                  1                2
# Min                        3                  1                2
# 90s                        3                  1                2
# Gls                        3                  1                2
# Ast                        3                  2                1
# G-PK                       2                  1                2
# PK                         2                  2                1
# PKatt                      2                  2                1
# CrdY                       3                  1                2
# CrdR                       1                  1                1
# Gls_per_90                 2                  1                3
# Ast_per_90                 3                  2                1
# G+A_per_90                 3                  2                1
# G-PK_per_90                2                  1                3
# G+A-PK_per_90              3                  2                1
# xG                         3                  1                1
# npxG                       3                  1                2
# xA                         3                  2                1
# npxG+xA                    3                  1                1
# xG_per_90                  3                  1                1
# xA_per_90                  3                  2                1
# xG+xA_per_90               3                  2                1
# npxG_per_90                3                  1                2
# npxG+xA_per_90             3                  2                1

# %%
# ax = stats_and_ranks.plot.bar(y = 'Min',                            
#                               rot = 0)

# %%
ax = Stats_df.plot.bar(y = 'Min',
                       rot = 0
                      )

# %%
ax = Stats_df.plot.barh(y = 'Min',
                       rot = 45
                       )

# %%
ax = Stats_df.plot.barh(x = 'Min'  # ,
#                        rot = 0
                       )

# %%
ax = Stats_df.plot.barh(
#                         y = 'Player',                      
#                         x = 'Min',
                        
#                         rot = 0,
                        
#                         color = {'Eriksen':'gold',
#                                  'Luis Alberto':'aqua',
#                                  'Calhanoglu':'crimson'}
                        
#                         use_index = True,
                        
#                        index = 'Player'
                       )

# %%
ax = Stats_df.plot.barh(y = 'Min',
                        
                        rot = 25,
                        
                        #
                        
                        color = {'Eriksen':'gold',
                                 'Luis Alberto':'aqua',
                                 'Calhanoglu':'crimson'}
                        
                        #
                       )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-d40fbe92920f> in <module>
# ----> 1 ax = Stats_df.plot.barh(y = 'Min',
#       2
#       3                         rot = 25,
#       4
#       5                         #
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/pandas/plotting/_core.py in barh(self, x, y, **kwargs)
#    1191         other axis represents a measured value.
#    1192         """
# -> 1193         return self(kind="barh", x=x, y=y, **kwargs)
#    1194
#    1195     def box(self, by=None, **kwargs):
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     269         self._compute_plot_data()
#     270         self._setup_subplots()
# --> 271         self._make_plot()
#     272         self._add_table()
#     273         self._make_legend()
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1440             else:
#    1441                 w = self.bar_width / K
# -> 1442                 rect = self._plot(
#    1443                     ax,
#    1444                     self.ax_pos + (i + 0.5) * w,
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1488     @classmethod
#    1489     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1490         return ax.barh(x, y, w, left=start, log=log, **kwds)
#    1491
#    1492     def _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge):
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
#    2629         kwargs.setdefault('orientation', 'horizontal')
# -> 2630         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2631                            align=align, **kwargs)
#    2632         return patches
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2441
#    2442         linewidth = itertools.cycle(np.atleast_1d(linewidth))
# -> 2443         color = itertools.chain(itertools.cycle(mcolors.to_rgba_array(color)),
#    2444                                 # Fallback if color == "none".
#    2445                                 itertools.repeat('none'))
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     339         return np.zeros((0, 4), float)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#     343
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     339         return np.zeros((0, 4), float)
#     340     else:
# --> 341         return np.array([to_rgba(cc, alpha) for cc in c])
#     342
#     343
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     187         rgba = None
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#     191             _colors_full_map.cache[c, alpha] = rgba
#
# ~/.conda/envs/interpool_py_3_8_env/lib/python3.8/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     258                     f"Value must be within 0-1 range")
#     259             return c, c, c, alpha if alpha is not None else 1.
# --> 260         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     261     # tuple color.
#     262     if not np.iterable(c):
#
# ValueError: Invalid RGBA argument: 'Eriksen'

# %%
ax = Stats_df.plot.barh(subplots = True,
                        
#                         use_index = False
                        
                        layout = (25,1  # (rows,columns)
                                 ),
                        
                        figsize = (5, 125),
                        
                        sharex = False
                        
                        #
                        
                        #
                       )

# %%
ax = Stats_df.plot.barh(subplots = True,
                        
#                         use_index = False
                        
                        layout = (13,2  # (rows,columns)
                                 ),
                        
                        figsize = (10, 125),
                        
                        sharex = False
                        
                        #
                        
                        #
                       )

# %%
ax = Stats_df.plot.barh(subplots = True,
                        
                        layout = (9,  # (rows)
                                  3    # (columns)
                                 ),
                        
                        figsize = ( # 20,80
                                   15,70
                                  ),
                        
                        xlabel = " ",   # False,
                        
#                         ylabel = False,
                        
#                         rot = 90,
                        
                        #
                        
                        sharex = False,
                        
                        sharey = True,
                        
                        #
                        
                        legend = False
                        
                        #
                        
                        #
                       )

# %%
ax = Stats_df.plot.barh(subplots = True,
                        
                        layout = (13,  # (rows)
                                  2   # (columns)
                                 ),
                        
                        figsize = (10,  # width (inches)
                                   80  # height (inches)
                                  ),
                        
                        xlabel = " ",   # False,
                        
#                         ylabel = False,
                        
#                         rot = 90,
                        
                        #
                        
                        sharex = False,
                        
                        sharey = True,
                        
                        #
                        
                        legend = False
                        
                        #
                        
                        #
                       )

# %% [markdown]
# ax = sns.lmplot(
#                 x = #####   'Press',
#
#                 y = #####   'Press_Succ_Pct',
#
#                 data = #####   Defensive_Actions_df,
#
#
#
#                 fit_reg = True,
#                 #fit_reg = False,         # for *NO* regression line
#
#                 height = 13,
#                 aspect = 1.3      #  dimension of x-axis (sets width)
#                )
#
# #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# x_col_min = #####   Defensive_Actions_df[   #####   'Press'].min()
#
# x_col_max = #####   Defensive_Actions_df[   #####   'Press'].max()
#
#
# y_col_min = #####   Defensive_Actions_df[   #####   'Press_Succ_Pct'].min()
#
# y_col_max = #####   Defensive_Actions_df[   #####   'Press_Succ_Pct'].max()
#
#
#
#
#
# #plt.xlim((x_col_min - 1), (x_col_max + 1))
# #plt.ylim((y_col_min - 1), (y_col_max + 1))
#
# plt.xlim(
#          (x_col_min * 0.96),
#          (x_col_max * 1.01)
#         )
# plt.ylim(
#          (y_col_min * 0.97),
#          (y_col_max * 1.03)
#         )
#
# #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#
#
#
# # identify the source variables in MAIN TITLE:
#
# plt.suptitle(
#                        #####   'PRESSURES - TOTAL vs SUCCESS RATE     ',
#
#              x = 0.475,
#              y = 1.01,
#
#              fontsize = 29,
#
#              color = 'yellow'
#             )
#
#
#
#
# # identify the source time period in SUBTITLE:
#
# plt.title(
#           #####   subtitle_2_lines,
#
#
#           loc = 'left',
#
#           fontsize = 15,
#
#           alpha = 0.9,
#
#           style = 'italic',
#
#           color = 'goldenrod'
#          )
#
#
#
#
# # attribute this work to "InterPool" specifically for S.O.M.
#
# plt.title(
#           #####   prod_by_and_for,
#
#
#           loc = 'right',
#
#           fontsize = 15,
#
#           alpha = 0.7,
#
#           style = 'italic',
#
#           color = 'lightblue'
#          )
#
# #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# plt.xlabel(
#           #####   'PRESSURES - TOTAL',
#
#            fontsize = 25,
#
#            color = 'yellow'
#           )
#
# plt.ylabel(
#           #####   'PRESSURES - SUCCESS RATE (%)',
#
#            fontsize = 25,
#
#            color = 'yellow'
#           )
#
# #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#
# # plt.figimage(
# #              logos_flat_small,
#
# #              980,   # 1090
# #              5
# #             )
#
#
# #- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# point_labels = [
#                 plt.text(
#                          #####   Defensive_Actions_df.          #####   Press[i],
#
#                          #####   Defensive_Actions_df.          #####   Press_Succ_Pct[i],
#
#                          #####   Defensive_Actions_df.          #####   Squad[i],
#
#                          fontsize = 18
#
#                         ) for i in range(
#                                          len(
#                                              #####   Defensive_Actions_df.Squad
#                                             )
#                                         )
#                ]
#
#
# adjust_text(
#             point_labels,
#
#             arrowprops = dict(
#                               arrowstyle = '->',
#                               color = 'red'
#                              )
#            )
